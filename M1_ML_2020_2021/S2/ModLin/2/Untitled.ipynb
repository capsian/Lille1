# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.model_selection import train_test_split
from numpy.linalg import inv
import sklearn

# %%
def datagen(n):
    X = np.random.rand(n,2)
    print(X)
    d_i = []
    r_i = []
    p_i = []
    for x_i,y_i in X:
        # calcul de distance
        d_i.append(abs(( (-0.5) * x_i - y_i +0.75 )) / (np.sqrt( (-0.5)**2 + 1) ))
        r_i.append(np.exp( -(d_i[-1]**2) / (2*0.05)**2 ))
        p_i.append( np.random.binomial(p=r_i[-1]/2,n=1) )
    return X,p_i

# %%
N=300
X,y=datagen(N)
for a in range(N):
    if X2_d[a]>X[:,1][a]:
        y[a]=1
plt.scatter(X[:,0],X[:,1],c=y,cmap='cool',s=5)
X2_d=(-0.5*X[:,0])+(0.75)
plt.plot(X[:,0],X2_d)
# Out:
# [[0.51217412 0.39693218]
#  [0.07840104 0.64268272]
#  [0.44665195 0.00936295]
#  [0.51726137 0.48163185]
#  [0.05870303 0.78926036]
#  [0.86916737 0.60515076]
#  [0.34058198 0.38757694]
#  [0.21857786 0.88323705]
#  [0.72714616 0.91237914]
#  [0.46026892 0.14429321]
#  [0.27265034 0.50150162]
#  [0.45708479 0.58141668]
#  [0.04134879 0.88944063]
#  [0.62781573 0.11453058]
#  [0.02972194 0.7544399 ]
#  [0.52292407 0.776136  ]
#  [0.44734813 0.01872688]
#  [0.96582943 0.64656369]
#  [0.01008732 0.86702572]
#  [0.91829936 0.13194814]
#  [0.43587875 0.72751466]
#  [0.30157953 0.26000016]
#  [0.4807695  0.83216521]
#  [0.81313392 0.78268368]
#  [0.04781164 0.93615038]
#  [0.12985727 0.77552346]
#  [0.4760627  0.8429552 ]
#  [0.9631624  0.84913721]
#  [0.44823582 0.57884997]
#  [0.80193027 0.78044843]
#  [0.96231526 0.41908524]
#  [0.5677673  0.64690717]
#  [0.56064344 0.79831833]
#  [0.1482846  0.8400547 ]
#  [0.80076546 0.02607565]
#  [0.21590415 0.94992712]
#  [0.39889124 0.12045068]
# ...
