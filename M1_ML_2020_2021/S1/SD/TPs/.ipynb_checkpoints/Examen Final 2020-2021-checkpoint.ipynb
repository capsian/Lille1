# %% [markdown]
# # Exercices, solutions illustrées par des exemples (3 * 1 = 3 points)
#
# Pour chaque exercice dans cette section donner une réponse vrai/faux et un exemple illustrant chacune de vos réponses. **Les points ne sont comptés que par la présence de l'exemple**. L'exemple peut être un jeu de données minimal, ou expliqué en quelques mots.

# %% [markdown]
# **Question**
# La règle majoritaire est basique car elle n'utilise pas les valeurs des attributs décrivant les données pour sa décision. Une méthode de classification qui va utiliser les valeurs des atttributs donne *toujours* un meilleur résultat.

# %% [markdown]
# *Réponse* :
#
# Pas nécéssairement...
# Contre exemple: On peut utiliser l'aggregation de plusieurs apprenants faibles qui surpassent un classifieur qui utilise tout les attributs. (Methode d'ensemble)
# Contre exemple2: Si tous les attributs sont corrélées, la méthode qui utilise tous les attributs peut etre fausse

# %% [markdown]
# **Question**
# Les données d'une colonne A sont comprises entre 1.1e-5 et .9e-5, l'écart type est de 1e-6, les valeurs des autres colonnes de B à Z sont comprises entre 1 et 100 et l'écart type est 5.
#    1. [ ] La colonne A est inutile on peut la supprimer car les valeurs sont trop petites
#    2. [ ] La colonne A est inutile on peut la supprimer car les valeurs sont trop ressérées
#    3. [ ] Il faut absolument garder la colonne A car les valeurs sont vraiment différentes
#    4. [X] On ne peut pas conclure s'il faut garder ou supprimer la colonne A
#    5. [ ] On peut ne garder qu'une seule des colonnes de B à Z

# %% [markdown]
# *Réponse*
#
# On ne peut pas conclure s'il faut garder ou supprimer la colonne A.
# En effet, on ne connait pas l'importance de cet attribut.
# Par contre il est nécéssaire de scaler !

# %% [markdown]
# **Question**
# J'ai un problème de classification. Il est important de calculer la micro et la macro average quand
#    1. [ ] Il n'y a que deux classes
#    2. [X] Il y a plus de deux classes
#    3. [X] Les classes sont très déséquilibrées
#    4. [ ] Il y a beaucoup de classes (plus de 10)

# %% [markdown]
# *Réponse*
#
# On utilise la macro et la micro average quand on a plus de deux classes, sinon c'est binaire.
# On utilise le score micro lorsqu'il est nécessaire de pondérer chaque instance ou prédiction de manière égale.
# On utilise le score macro lorsque toutes les classes doivent être traitées de manière égale pour évaluer les performances globales du classificateur en ce qui concerne les étiquettes de classe les plus fréquentes.

# %% [markdown]
# # Exercices (1 + 2 + 2 + 2 = 7 points)

# %% [markdown]
# Répondez par une réelle explication aux questions suivantes.

# %% [markdown]
# **Question**
# J'ai calculé ma matrice de correlations entre les 100 colonnes de mon jeu de données. J'ai trouvé que les colonnes A et B sont correlées avec une valeur de 0.96, A et C sont corrélées avec une valeur de -0.98, et B et D sont correlées avec une valeur de .23 et A et E avec une valeur de 0.01. Que suggérez vous de faire ?

# %% [markdown]
# *Réponse* :
#
# A & B = 0.96
# ==> Forte correlation: on peut les enlever
#
# A & C = -0.98
# ==> Ne sont pas corrélées: on les garde
#
# B & D =  0.23
# ==> On peut essayer avec et sans
#
# A & E = 0.01
# ==> Faiblement corréles: on les garde

# %% [markdown]
# **Question**
# J'ai exécuté le code suivant
#
#       data = pd.read_csv("dataset.csv")
#       X = data.loc[:, data.columns != "label"]
#       y = data["label"]
#       X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
#       dtree = DecisionTreeClassifier()
#       print(dtree.fit(X_train, y_train).score(X_test, y_test))
#       X_scaled = scale(X)
#       X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33)
#       print(dtree.fit(X_train, y_train).score(X_test, y_test))
#
#    et j'ai obtenu les scores suivants 0.45 et 0.98. Que concluez-vous ?

# %% [markdown]
# *Réponse*
#
# On conclue que les données ne sont pas normalisées, les échelles des variables sont très différentes, il faut les scaler !

# %% [markdown]
# **Question**
# J'ai exécuté le code suivant
#
#       data = pd.read_csv("dataset.csv")
#       X = data.loc[:, data.columns != "label"]
#       y = data["label"]
#       X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
#       lr = LogisticRegression()
#       print(lr.fit(X_train, y_train).score(X_test, y_test))
#       X_train_scaled = scale(X_train)
#       print(lr.fit(X_train_scaled, y_train).score(X_test, y_test))
#
#    et j'ai obtenu les scores suivants 0.67 et 0.32. Que concluez-vous ?

# %% [markdown]
# *Réponse*
#
# On conclue que les données étaient déja normalisées !
# Perte des échelles des var
# Il ne fallait pas scaler !!

# %% [markdown]
# **Question**
# J'ai exécuté le code suivant
#
#       data = pd.read_csv("dataset.csv")
#       X = data.loc[:, data.columns != "label"]
#       y = data["label"]
#       clfs = [GaussianNB(),
#               SVC(),
#               LogisticRegression(max_iter=10000),
#               DecisionTreeClassifier(criterion="entropy"),
#               RandomForestClassifier()]
#       for clf in clfs:
#           clf.fit(X, y)
#       for clf in clfs:
#           print("{}:{}".format(clf.__class__.__name__, clf.score(X, y)))
#    et j'ai obtenu
#
#       GaussianNB:0.67
#       SVC:0.82
#       LogisticRegression:0.79
#       DecisionTreeClassifier:0.98
#       RandomForestClassifier:0.99
#    Quel est le meilleur classifieur ? Que proposez-vous de faire ?

# %% [markdown]
# *Réponse*
#
# On peut miser sur le RandomForest ou le DecisionTree, mais ce n'est pas abosolue !
#
# Ici on fait une erreur de méthodologie, il faut utiliser la cross validation pour avoir une erreur généralisée, on ne sait pas si le clf aura les memes res sur un autre échantillon.

# %% [markdown]
# # Entraînement de réseau de neurones (5 * 2 = 10 points)

# %% [markdown]
# **Question** Lire le fichier de données `dataset.csv`. L'attribut à prédire est la colonne `label`. Enlever les attributs `file_name`, `spectral_rolloff`, `spectral_bandwidth`, `melspectogram`, `delta`. Normaliser les colonnes restantes. Préparer l'échantillon en prenant 1/4 pour le test. Construire un réseau de neurones avec 2 couches cachées contenant 100 et  50 neurones, activation relu et autres paramètres par défaut. Afficher les erreurs en test et apprentissage.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns ; sns.set()

# %%
data = pd.read_csv("dataset.csv")
data.describe(include="all")
# Out:
#                                    file_name  zero_crossing  \
# count                                   1742    1742.000000
# unique                                  1742            NaN
# top     22. Cholo Bangladesh Music Video.mp3            NaN
# freq                                       1            NaN
# mean                                     NaN  215007.465557
# std                                      NaN   89920.930842
# min                                      NaN       0.000000
# 25%                                      NaN  152359.000000
# 50%                                      NaN  196971.500000
# 75%                                      NaN  257056.250000
# max                                      NaN  757737.000000
#
#         spectral_centroid  spectral_rolloff  spectral_bandwidth  \
# count         1742.000000       1742.000000         1742.000000
# unique                NaN               NaN                 NaN
# top                   NaN               NaN                 NaN
# freq                  NaN               NaN                 NaN
# mean          2015.700468       4100.426211         2043.560009
# std            721.696480       1597.279461          666.244323
# min              0.000000          0.000000            0.000000
# 25%           1533.507050       2962.049702         1699.097722
# 50%           2033.964745       4226.889780         2223.573271
# 75%           2495.077302       5258.493696         2532.093962
# max           5323.086970       8810.877261         3252.209261
#
#         chroma_frequency         rmse         delta  melspectogram  \
# count        1742.000000  1742.000000  1.742000e+03    1742.000000
# unique               NaN          NaN           NaN            NaN
# top                  NaN          NaN           NaN            NaN
# freq                 NaN          NaN           NaN            NaN
# mean            0.305385     0.171471 -1.743660e-09       8.522913
# std             0.072464     0.075168  1.393930e-07       7.374733
# min             0.000000     0.000000 -1.676001e-06       0.000000
# 25%             0.249591     0.118410 -6.728298e-08       3.576854
# 50%             0.294676     0.160642  1.617425e-10       6.477533
# 75%             0.351839     0.214249  6.924068e-08      11.528968
# max             0.616620     0.628826  6.417627e-07      83.923833
#
#               tempo  ...       mfcc11       mfcc12       mfcc13       mfcc14  \
# count   1742.000000  ...  1742.000000  1742.000000  1742.000000  1742.000000
# unique          NaN  ...          NaN          NaN          NaN          NaN
# top             NaN  ...          NaN          NaN          NaN          NaN
# freq            NaN  ...          NaN          NaN          NaN          NaN
# mean     123.112315  ...     0.117813    -5.085212    -1.104625    -4.488481
# std       21.849677  ...     5.985646     5.253280     5.643891     4.682304
# min       73.828125  ...   -25.692529   -24.642862   -26.359570   -23.886369
# 25%      107.666016  ...    -3.046898    -8.325668    -3.995158    -7.407150
# 50%      123.046875  ...     0.643217    -4.750612    -0.513353    -4.537535
# 75%      135.999178  ...     3.916396    -1.735095     2.440787    -1.597814
# max      184.570312  ...    20.077568    14.958208    16.891013    24.020983
#
#              mfcc15       mfcc16       mfcc17       mfcc18       mfcc19  \
# count   1742.000000  1742.000000  1742.000000  1742.000000  1742.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      -0.222948    -4.636100     0.331630    -4.160293    -0.704487
# std        4.659930     4.515759     4.447436     4.531011     4.433841
# min      -20.935224   -21.520218   -17.205040   -24.743798   -16.665104
# 25%       -2.824771    -7.600435    -2.115535    -6.914308    -3.256649
# 50%        0.162360    -4.908912     0.495084    -4.428667    -0.535849
# 75%        2.756847    -2.071220     3.124587    -1.830402     2.015320
# max       20.451894    19.347293    19.915842    21.322978    20.967689
#
#          label
# count     1742
# unique       6
# top     nazrul
# freq       312
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
#
# [11 rows x 31 columns]

# %%
data = data.drop(["file_name", "spectral_rolloff", "spectral_bandwidth", "melspectogram", "delta"], axis=1)
data.describe(include="all")
# Out:
#         zero_crossing  spectral_centroid  chroma_frequency         rmse  \
# count     1742.000000        1742.000000       1742.000000  1742.000000
# unique            NaN                NaN               NaN          NaN
# top               NaN                NaN               NaN          NaN
# freq              NaN                NaN               NaN          NaN
# mean    215007.465557        2015.700468          0.305385     0.171471
# std      89920.930842         721.696480          0.072464     0.075168
# min          0.000000           0.000000          0.000000     0.000000
# 25%     152359.000000        1533.507050          0.249591     0.118410
# 50%     196971.500000        2033.964745          0.294676     0.160642
# 75%     257056.250000        2495.077302          0.351839     0.214249
# max     757737.000000        5323.086970          0.616620     0.628826
#
#               tempo        mfcc0        mfcc1        mfcc2        mfcc3  \
# count   1742.000000  1742.000000  1742.000000  1742.000000  1742.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     123.112315  -138.582862   107.790241    -8.954828    20.100432
# std       21.849677    85.633145    38.721908    24.725244    19.556501
# min       73.828125 -1131.370850    -5.494149  -121.531185   -71.378921
# 25%      107.666016  -191.413937    81.129602   -23.948426    12.506260
# 50%      123.046875  -127.380986   101.753613    -4.904458    20.353824
# 75%      135.999178   -78.053853   129.422730     8.438774    30.269945
# max      184.570312   103.939519   240.739685    72.432374   106.666558
#
#               mfcc4  ...       mfcc11       mfcc12       mfcc13       mfcc14  \
# count   1742.000000  ...  1742.000000  1742.000000  1742.000000  1742.000000
# unique          NaN  ...          NaN          NaN          NaN          NaN
# top             NaN  ...          NaN          NaN          NaN          NaN
# freq            NaN  ...          NaN          NaN          NaN          NaN
# mean      -2.600265  ...     0.117813    -5.085212    -1.104625    -4.488481
# std       13.452756  ...     5.985646     5.253280     5.643891     4.682304
# min      -66.035766  ...   -25.692529   -24.642862   -26.359570   -23.886369
# 25%      -10.176963  ...    -3.046898    -8.325668    -3.995158    -7.407150
# 50%       -1.319737  ...     0.643217    -4.750612    -0.513353    -4.537535
# 75%        5.759499  ...     3.916396    -1.735095     2.440787    -1.597814
# max       45.119647  ...    20.077568    14.958208    16.891013    24.020983
#
#              mfcc15       mfcc16       mfcc17       mfcc18       mfcc19  \
# count   1742.000000  1742.000000  1742.000000  1742.000000  1742.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      -0.222948    -4.636100     0.331630    -4.160293    -0.704487
# std        4.659930     4.515759     4.447436     4.531011     4.433841
# min      -20.935224   -21.520218   -17.205040   -24.743798   -16.665104
# 25%       -2.824771    -7.600435    -2.115535    -6.914308    -3.256649
# 50%        0.162360    -4.908912     0.495084    -4.428667    -0.535849
# 75%        2.756847    -2.071220     3.124587    -1.830402     2.015320
# max       20.451894    19.347293    19.915842    21.322978    20.967689
#
#          label
# count     1742
# unique       6
# top     nazrul
# freq       312
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
#
# [11 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

X = scale(data.loc[:, data.columns != "label"])
y = data["label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.model_selection import cross_validate

def evaluate_classifiers(clfs, names, X, y):
    scores = {}
    best = None
    best_score = 0
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    
    print("CROSS VALIDATION OVER 5 FOLDS")
    print("==========================")

    for clf, name in zip(clfs, names):
        scores[clf] = cross_validate(clf, X_train, y_train, 
                                     return_train_score=True, cv=5,
                                     return_estimator=True)
        
        train_scores = scores[clf]["train_score"]
        valid_scores = scores[clf]["test_score"]
        test_scores = [est_clf.score(X_test, y_test) for est_clf in scores[clf]["estimator"]]

        print(name)
        print("\tTraining time mean: %.2f" % np.mean(scores[clf]["fit_time"]))
        print("\tTrain mean: %.2f" % np.mean(train_scores))
        print("\tValidation mean: %.2f" % np.mean(valid_scores))     
        print("\tTest: %.2f" % clf.fit(X_train, y_train).score(X_test, y_test))
        print()
        
        if(np.mean(valid_scores) > best_score):
            best_score = np.mean(valid_scores)
            best = clf
            best_name = name
            
    print("Best Classifier (according to validation): ", name, "with mean score %.2f" % best_score)

    
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(activation='relu' ,hidden_layer_sizes=(100, 50), random_state=42)


evaluate_classifiers([clf], ["MLP"], X, y)
# Out:
# CROSS VALIDATION OVER 5 FOLDS
# ==========================
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP
# 	Training time mean: 1.17
# 	Train mean: 1.00
# 	Validation mean: 0.69
# 	Test: 0.71
#
# Best Classifier (according to validation):  MLP with mean score 0.69
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# **Question**
# En utilisant l'attribut `loss_curve_` tracer la courbe montrant l'évolution de la fonction de perte au cours des itérations.

# %%
plt.plot(clf.loss_curve_)
plt.show()

# %% [markdown]
# **Question** Commentez la courbe

# %% [markdown]
# *Réponse*
#
# La courbe décroit en augmentant les itération. (Reduction de la perte)

# %% [markdown]
# **Question** Selon vos résultats, quelle classe est la plus difficile à prédire et quelle classe est la plus facile à prédire ? Justifiez votre analyse par un affichage grâce à quelques fonctions de mesure de `sklearn`.

# %%
data["label"].value_counts() / len(data["label"])
# Out:
# nazrul        0.179104
# rabindra      0.170494
# band          0.169346
# hiphop        0.169346
# adhunik       0.162457
# palligeeti    0.149254
# Name: label, dtype: float64

# %% [markdown]
# *Réponse*
#
# On remarque que la classe la plus présente est la nazrul donc elle devrait être plus facile à prédire.
# Par contre la classe palligeeti est la classe la moins présente, elle devrait être plus difficile à prédire.

# %% [markdown]
# **Question** Faites varier la taille de la première et unique couche cachée entre 10 et 150 par pas de 20 et  afficher les courbes d'erreur en apprentissage et en validation en fonction de la complexité du modèle. L'erreur en validation est estimée par validation croisée 5 fois.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve

parameters = {
    'hidden_layer_sizes': np.arange(10, 150, 20)
}
clf2 = GridSearchCV(MLPClassifier(), parameters, cv=5)

# %%
train_sizes, train_scores, valid_scores = learning_curve(clf2, X, y, cv=5)
# Out:
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/m1ml/lakhdar/.conda/envs/ds/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(valid_scores, axis=1)
test_scores_std = np.std(valid_scores, axis=1)

# Plot learning curve
plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
plt.legend(loc="best")

# %%
#clf2.fit(X_train, y_train)
#print(clf2.score(X_test, y_test))
#print(clf2.best_params_)

# %% [markdown]
# # Calcul de backprop (2 * 2 = 4 points)

# %% [markdown]
# Soit le réseau suivant où toutes les fonctions d'activation sont des sigmoïdes
#
# ![image.png](attachment:image.png)

# %%
def sigmoide(x):
    return 1/(1+np.exp(-x))

# %% [markdown]
# **Question**
# Avec $\vec w = (1, .5, 0, 1, .5, .5, 1, .5, 1)$ et $\vec x=(1, 2, 1)$ et $y=1$. Appeler `oi` la sortie du neurone $f_i$. Appeler `E` la moitié de l'erreur quadratique. Calculez toutes ces quantités.

# %%
w = np.array([1, .5, 0, 1, .5, .5, 1, .5, 1]).reshape(-1,1)
x = np.array([1,2,1]).reshape(-1,1)
z1 = w[0] * x[0] + w[1] * x[1]
z2 = w[2] * x[1] + w[3] * x[2]
z3 = z1 * w[4]
z4 = z1 * w[4] + z2 * w[6]
z5 = z3 * w[7] + z4 * w[8]

o1 = sigmoide(z1)
o2 = sigmoide(z2)
o3 = sigmoide(z3)
o4 = sigmoide(z4)
o5 = sigmoide(z5)


y = 1
E = 0.5 * (o5 - y)**2
print(E)
# Out:
# [0.00287723]

# %% [markdown]
# **Question**
# Si le pas de gradient est 0.1, quelle est la valeur de w3 mise à jour après rétropropagation du gradient ?

# %%
# Plus de temps :(
# On doit, calculer l'err en fonc de chaque neurone à partir de l'output vers l'input
