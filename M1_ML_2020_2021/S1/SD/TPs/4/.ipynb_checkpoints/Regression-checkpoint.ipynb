# %% [markdown]
# # Regression

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
rng = np.random.RandomState(42)

# %% [markdown]
# **Question** Faire un jeu de 1000 données tirées aléatoirement avec une loi normale multidimensionnelle (multivariée) centrée en $(0,0)$ de matrice de covariance.
#
# $$\left(\begin{array}{cc}2.0 & 1.5\\1.5&2.0\end{array} \right)$$
#
# C'est donc être une matrice de nombres aléatoires de 1000 par 1000 que vous appelez `data1`. *Aide* Regardez dans le module `random`...

# %%
mean = [0,0]
cov = [[2.0,1.5],[1.5,2.0]]

# %%
data1 = np.random.multivariate_normal(mean,cov,1000)
print(data1.shape)
print(data1)
# Out:
# (1000, 2)
# [[-0.48965492  0.23546356]
#  [-1.24111679 -2.5551503 ]
#  [ 0.04679427 -1.01004899]
#  ...
#  [ 0.04194801 -1.02853866]
#  [ 2.64632217  0.78151053]
#  [-1.14510547 -0.93167797]]

# %% [markdown]
# **Question** Vérifiez que la moyenne et la variance sont bien proches de ce qui est attendu.

# %%
np.mean(data1)
# Out:
# -0.011230540925079698

# %%
np.var(data1)
# Out:
# 2.006355141870431

# %% [markdown]
# **Question** La matrice `X1` a 1000 lignes et 1 colonne (1000,1) et c'est la première colonne de vos données. Le vecteur `y1` est de dimension (1000,) et c'est la seconde colonne de vos données. Définissez `X1` et `y1` et tracez le nuage de points

# %%
X1 = np.array([row[0] for row in data1]).reshape(1000,1)
y1 = np.array([row[1] for row in data1])
print(X1.shape)
print(y1.shape)

plt.plot(X1, y1, 'x')
plt.axis('equal')
plt.show()
# Out:
# (1000, 1)
# (1000,)

# %% [markdown]
# **Question** Faire un modèle de régression linéaire `r1` (sans intersection à l'origine puisque le nuage est centré en (0,0) ) et l'entraîner avec `X1` et `y1`.

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

X_train, X_test, Y_train, Y_test = train_test_split(X1, y1, test_size = 0.3, random_state=42)
r1 = linear_model.LinearRegression(fit_intercept=False)
r1.fit(X_train,Y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %% [markdown]
# **Question** Observez le coefficient dans `r1._coef`

# %%
print(r1.coef_)
print(r1.intercept_)
# Out:
# [0.7730097]
# 0.0

# %% [markdown]
# **Question** Calculer les prédictions de `r` sur les données de `X1`. On appelle ce vecteur `y1_pred`... C'est une droite

# %%
y1_pred = r1.predict(X_train)

# %% [markdown]
# **Question** Tracer le nuage avec la droite en rouge

# %%
fig, ax = plt.subplots()
ax.scatter(X_train, Y_train)
ax.plot([X_train.min(), X_train.max()], [y1_pred.min(), y1_pred.max()], color='r')  # tracer la diagonale

#ax.plot(X_train, y1_pref, color='r')
plt.show()

# %% [markdown]
# Avec les moindres carrés, on calcule
#
# $$\mathop{\mathrm{argmin}}_a \sum_{x,y\in X_1\times y_1}  (ax - y)^2$$

# %% [markdown]
# **Question** Développer et calculer la dérivée par rapport à $a$ et chercher où la dérivée s'annule. Vérifier que vous obtenez le même résultat que le coefficient de $r1$.

# %% [markdown]
# *Réponse*: (calcul de la dérivée)

# %%
# (ax - y)² = (ax)² - 2axy - y²
# On dérive suivant a
# 2ax² - 2xy
# On cherche où la dérivée s'annule
# 2ax² = 2xy <=> a = xy / x² 

a = np.dot(Y_train,X_train).sum() / np.power(X_train,2).sum()
print(a)
print(r1.coef_)
# Out:
# 0.7730096976170799
# [0.7730097]

# %% [markdown]
# Sous forme matricielle on peut réécrire
#
# $$\mathop{\mathrm{argmin}}_a \sum_{x,y\in X_1\times y_1}  (ax - y)^2  = \mathop{\mathrm{argmin}}_a \Vert aX_1-y_1 \Vert^2$$
#
# **Question** Sachant que pour un vecteur $x$ on a $\Vert x \Vert^2 = \langle x,x\rangle = x^\top x$ et en utilisant la distributivité de la multiplication sur l'addition, réécrivez le développement et la dérivée sous forme matricielle.

# %% [markdown]
# *Réponse* :

# %%
# ||aX1 - Y1||² = (aX1 - Y1).T (aX1 - Y1)
# => (aX1.T - Y1.T) (aX1 - Y1)
# => (a²X1.TX1 - aX1.TY1 - Y1.TaX1 + Y1.TY1)
# => a²X1.TX1 - 2aX1.TY1 + Y1.TY1
# on dérive suivant a
# => 2aX1.TX1 - 2X1.TY1
# =>> 2aX1.TX1 - 2X1.TY1 = 0 || 2aX1.TX1 = 2X1.TY1 || aX1.TX1 = X1.TY1 || a = X1.TY1 / X1.TX1 
# ==>> a = X1.T*Y1*inv(X1.TX1)

# %% [markdown]
# **Question** Maintenant en supposant que $X_1^TX_1$ est définie positive, (elle est positive), et donc possède une inverse et sachant que $A^{-1}A$ est l'identité pour toute matrice $A$ inversible, exprimez de façon matricielle la valeur de $a$ et calculez-la de cette façon.
#
# _Aide_ : `np.linalg.inv(A)` inverse une matrice, `np.dot(A,B)` fait une multiplication de matrice, une autre notation est `A@B`.

# %% [markdown]
# *Réponse* : La dérivée s'annule si ... (à compléter)

# %%
a = X_train.T@Y_train / (X_train.T@X_train)
a1 = X_train.T@Y_train@np.linalg.inv((X_train.T@X_train))
print(a)
print(a1)

print(r1.coef_)

# De façon générale la dérivée s'annule dans un max ou un min de la fonction
# La dérivée s'annule si, X1.T*Y1 = 0  (??)
# Out:
# [[0.7730097]]
# [0.7730097]
# [0.7730097]

# %% [markdown]
# **Remarque** Le calcul qu'on vient de faire est toujours correct quand la matrice $X_1$ a plus d'une seule colonne!

# %% [markdown]
# ## Avec un nuage de points qui n'est pas centré...

# %% [markdown]
# On génère à nouveau ces données mais cette fois avec des données centrées en $(3,2)$ pour la même matrice de covariance. Nous allons recommmencer mais notre calcul analytique est désormais faux si on ne prend pas en compte l'ordonnée à l'origine...
#
# **Question**  Générer les données, tracer les données, la droite de régression comme au début de ce TD. On appelle les nouveaux objets `data2`, `X2`, `y2`, et `r2`.

# %%
data2 = np.random.multivariate_normal((3,2),cov,1000)

X2 = np.array([row[0] for row in data2]).reshape(1000,1)
y2 = np.array([row[1] for row in data2])
print(X2.shape)
print(y2.shape)

plt.plot(X2, y2, 'x')
plt.axis('equal')
plt.show()
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, y2, test_size = 0.3, random_state=42)
r2 = linear_model.LinearRegression()
r2.fit(X2_train,Y2_train)
y2_pref = r2.predict(X2_train)

fig, ax = plt.subplots()
ax.scatter(X2_train, Y2_train)
ax.plot([X2_train.min(), X2_train.max()], [y2_pref.min(), y2_pref.max()], color='r')  # tracer la diagonale
plt.show()
# Out:
# (1000, 1)
# (1000,)

# %% [markdown]
# On doit désormais résoudre
#
# $$\mathop{\mathrm{argmin}}_{a,b} \sum_{x,y\in X_2\times y_2}  (ax + b - y)^2$$
#
# Mais c'est un peu plus pénible à résoudre, sauf si on suit l'écriture matricielle. Un petit truc est d'écrire
#
# $$\mathop{\mathrm{argmin}}_{a,b} \sum_{x,y\in X_2\times y_2}  (ax + b - y)^2=\mathop{\mathrm{argmin}}_{a,b} \Vert aX_2 + b\mathbf 1 -y_2 \Vert^2$$
#
# où $\mathbf 1$ est un vecteur de 1 de dimension de $X_2$. Donc si j'appelle $w=(a,b)^\top$ et $X_{2b}$ est $X_2$ à laquelle on a ajouté une colonne de 1, cela s'écrit
#
# $$\mathop{\mathrm{argmin}}_{w} \Vert X_{2b}w  -y_2 \Vert^2$$
#
# Et donc on peut refaire le même calcul que précédemment!  Il suffit donc d'ajouter une dimension au problème et de la mettre à 1...
#
# **Question** Créer une matrice `X2b` en conséquence

# %%
ones = np.ones((len(X2_train),1))
X2b = np.hstack((X2_train,ones))
X2b
# Out:
# array([[3.38696404, 1.        ],
#        [2.20709259, 1.        ],
#        [4.10029595, 1.        ],
#        ...,
#        [5.3898459 , 1.        ],
#        [3.78567809, 1.        ],
#        [2.40813575, 1.        ]])

# %% [markdown]
# **Question** Résoudre maintenant le système avec les opérateurs matriciels comme précédemment.

# %%
# || X2b*w - y2 ||² = (X2b*w - y2).T * (X2b*w - y2)
# X2b.T*w*X2b*w - X2b.T*w*y2 - y2.T*X2b*w + y2.T*y2
# w²*X2b.T*X2b - w(X2b.T*y2 + y2.T*X2b) + y2.T*y2
# On dérive suivant w
# 2w*X2b.T*X2b - 2X2b.T*y2
# On cherche ou ça s'annule
# w*X2b.T*X2b = X2b.T*y2
# w = X2b.T*y2 / X2b.T*X2b 
# w = inv(X2b.T*X2b) * X2b.T*y2


a2 = np.linalg.inv(X2b.T@X2b)@X2b.T@Y2_train
print(a2)
print(r2.coef_)
print(r2.intercept_)
# Out:
# [ 0.76901896 -0.2885801 ]
# [0.76901896]
# -0.2885800984489115

# %% [markdown]
# ## Approche par descente de gradient

# %% [markdown]
# L'approche précédente se généralise. La fonction derrière le `argmin` est ce qu'on appelle une **fonction objectif** (ou fonction de perte) et l'approche est de trouver les paramètres qui minimisent cette perte.
#
# $$\mathop{\mathrm{argmin}}_{w} f(X, y, w)$$

# %% [markdown]
# **Question** Quelle est la fonction objectif de l'exemple précédent avec la régression pour le nuage de points centré en $(3,2)$? (Reprennez les  mêmes objets $X_{2b}$ et $y_2$.

# %% [markdown]
# *Réponse*:

# %%
# La fonction objectif est:  X2b*w - y2

# %% [markdown]
# Dans le cas précédent, cela marche très bien car on minimise une fonction dérivable, convexe, il y a un minimum global et une solution analytique. Par ailleurs, la matrice est assez petite car il y a peu de données, mais si on a des *big data*, cela ne marche plus. Le calcul de l'inverse est trop long à calculer.

# %% [markdown]
# **Question** Quelle est la complexité en temps du calcul de l'inverse d'une matrice de dimension $n$ par $n$ ?

# %% [markdown]
# *Réponse* :

# %%
# https://www.dcode.fr/inverse-matrice
# L'inverse d'une matrice carrée se calcule de plusieurs façons. 
# La plus facile est la méthode des cofacteurs qui nécessite au préalable de calculer le déterminant de la matrice, 
# mais aussi la comatrice C (qui est la transposée de la matrice des cofacteurs)
# ...
# Sachant que l'on calcule principalement des produits de matrices le meilleur algo devrait être en n3 (??)

# %% [markdown]
# Moralité : en prenant plus de données ou des fonctions de perte plus compliquées pour lesquelles on n'a pas de solution analytique, il faut changer de façon de faire...
#
# Commençons par voir comment approcher la solution analytique par un autre moyen. L'idée ici est de suivre la pente de la courbe de la fonction de perte. On calcule donc la dérivée et on va dans la direction opposée à la dérivée par petites touches. (Voir [cette page](https://www.neural-networks.io/fr/single-layer/gradient-descent.php) pour les petits dessins qui font comprendre.)

# %% [markdown]
# L'algorithme part donc d'un point aléatoire (une valeur pour $w$ aléatoire), calcul la dérivée de la fonction objectif (notée $\nabla f$) et modifie $w$ avec un petit incrément qui est un facteur de cette dérivée. On appelle $\eta$ ce facteur.
#
# \begin{equation} w^{(t)} = w^{(t-1)} - \eta\nabla f(X, y, w^{(t-1)})\qquad (\text{Eq. } 1)
# \end{equation}
#
# Dans la suite, on déroule d'abord à la main cet algorithme pour un seul pas passant de l'étape $t=0$ à l'étape $t=1$, puis on écrit l'algorithme complet.

# %% [markdown]
# ### De t=0 à t=1

# %% [markdown]
# **Question** Tirez au hasard (nombres entre 0 et 1) un 1-d array de taille 2 pour représenter les 2 coefficients $a$ et $b$ de notre problème. Appelez-le `w_trans`

# %%
w_trans = np.random.randint(2, size=2)
print(w_trans)
# Out:
# [0 1]

# %% [markdown]
# **Question** Calculez la valeur de la fonction objectif pour cette valeur de `w_trans`

# %%
val = X2b@w_trans - Y2_train
print(val.shape)
# Out:
# (700,)

# %%
print(np.linalg.norm(val))
print(val)
# Out:
# 45.80831843173915
# [-1.17747861e+00 -5.87991806e-01 -2.16430389e+00 -2.61657216e+00
#  -2.42741526e+00 -1.04604341e+00 -4.37639439e+00 -1.58450758e+00
#  -2.01529782e+00  5.78488186e-01 -8.24913002e-01 -4.49687294e-01
#  -1.33316350e+00 -2.03220182e+00 -1.84963639e+00 -9.38746203e-01
#   3.81993503e-02 -5.31497548e-01  3.34650210e-01  1.28318893e-01
#   4.42923132e-02 -3.53997573e+00 -2.22425181e+00 -1.19055231e-01
#  -1.62077226e+00  8.62547321e-02  8.26231131e-01  1.10042827e+00
#  -2.27310827e+00 -4.00063498e+00  2.09594990e-01 -2.34275462e+00
#   4.04251475e-02  6.04082096e-01  8.27768013e-01 -4.92628428e-01
#  -1.57832641e+00 -2.62789375e+00  1.64370687e+00 -9.95797961e-01
#  -1.47828876e+00 -1.11262034e-01 -2.54041376e+00 -1.10843853e+00
#   4.82395983e-01 -6.32787665e-01 -2.39558821e-01 -4.90211166e-01
#  -2.48606307e+00 -5.19137035e-01 -1.78694441e+00 -5.07549527e-01
#  -2.21096604e+00  1.17817312e+00 -1.11174969e+00  3.99571123e-01
#  -6.16444018e-01 -1.68765010e+00 -5.54182612e-01 -1.06893566e+00
#  -1.54087921e+00 -2.13045302e+00  7.60041444e-01 -1.28727602e+00
#  -6.29853398e-01 -7.68444328e-01 -3.14633964e+00 -4.66917943e-01
#  -3.60068903e-01 -1.50472107e+00 -1.04907962e+00 -1.22813513e+00
#  -2.22626129e-01 -2.09642369e+00 -3.09357249e+00 -1.89872416e+00
#  -1.70802187e+00  9.89860908e-01 -7.29840318e-02 -3.26879211e-01
#  -3.30346305e-01 -1.09519182e+00  1.31615911e+00 -1.88885964e-01
#   4.69712281e-01  1.64343272e+00 -8.63630573e-01 -8.55126072e-01
#  -1.43344459e+00 -2.01276558e+00  3.29436948e-02 -1.18625284e+00
#  -6.62771842e-01 -1.88007039e+00  2.89513379e-02  2.58304174e-02
#  -8.45272176e-01 -7.35791468e-01 -1.85177639e+00 -8.33749677e-01
#   7.62511425e-01  2.14109873e+00 -2.72244405e+00 -1.25055346e-01
#  -3.44413739e+00  4.65669109e-01 -5.63103101e-01 -2.03333077e+00
#   1.21367181e+00 -4.34301296e+00 -4.43227818e-01  2.57114409e-01
#   6.02732321e-02 -3.76989304e+00 -1.32416159e+00 -1.48205460e+00]

# %% [markdown]
# Calculons la valeur de la dérivée de $\Vert X_{2b}w -y_2 \Vert^2$. On l'appelle `G`. C'est la dérivée d'une fonction de la forme $(h(x))^2$ et vaut donc $2h'(x)h(x)$ avec ici $h(x)$ est $E(X_{2b}, y_2, w)$, qui est l'erreur, la différence entre la valeur calculée et la valeur prédite (l'objectif c'est l'erreur quadratique).

# %% [markdown]
# La dérivée doit être calculée par rapport à chacun des paramètres, $a$ et $b$, C'est un vecteur de taille 2. Ici $h'$ est constante (c'est $X_{2}$) pour la première coordonnée ($a$) et 1 pour la seconde coordonnée ($b$), c'est donc $X_{2b}$. On calcule donc $E$, mais attention sous la forme d'une matrice (1000,1). `G` est une matrice de 1000 lignes et 2 colonnes.
#
# **Question** calculez `G`

# %%
E = (X2b@w_trans - Y2_train).reshape(700,1)
G = 2*X2b*E

# %%
print(G.shape)
# Out:
# (700, 2)

# %% [markdown]
# L'erreur comme l'objectif sont calculés comme une somme pour tous les points du jeu de données, la dérivée c'est aussi la somme des dérivées en chaque point de donnée.
# La valeur de la dérivée en ces paramètres `w_trans` est maintenant la somme de ces dérivées. C'est un vecteur de taille 2 qu'on notera ici `nabla`
#
# **Question** Calculez `nabla`

# %%
nabla = G.sum()
print(nabla)
# Out:
# -7538.442755899017

# %% [markdown]
# **Question** Fixez un pas de gradient `eta` de 0.00005, et calculez la nouvelle valeur de $w$ dans `w_trans_suivant` avec l'équation (Eq. 1)

# %%
eta = 0.00005
w_trans_suivant = w_trans - (eta * nabla)
print(np.linalg.norm(w_trans_suivant))
# Out:
# 1.4275800753406913

# %% [markdown]
# **Question** Recalculez la valeur de l'objectif dans `obj_suivant` et comparez avec la valeur de l'objectif avant d'effectuer ce pas de gradient.

# %%
obj_suivant = (X2b@w_trans_suivant) - Y2_train
print(obj_suivant.shape)
print(np.linalg.norm(w_trans_suivant))
# Out:
# (700,)
# 1.4275800753406913

# %% [markdown]
# ### Algorithme
#
# On repart maintenant de la nouvelle valeur et on itère. Globalement l'algorithme fait :
#
# ```
# Initialiser w aléatoirement
# t = 0
# Tant que t < n_iter:
#   Calculer l'erreur
#   Calculer le gradient
#   Modifier w avec l'Eq. 1
#   Incrémenter t
# ```

# %% [markdown]
# **Question** Écrire cet algorithme dans une fonction et l'essayer avec `X2b` et `y2` et `X1`, `y1`.

# %%
def regr(X, y, eta=0.00005, n_iter=100, verbose=False):
    """avec verbose=True on peut afficher la valeur de la fonction objectif """
    w = np.random.random(X.shape[1])
    
    t = 0
    while (t < n_iter):
        E = (X@w - y).reshape(X.shape[0], -1)
        if verbose:
           print("Objectif: " + str(np.linalg.norm(E)))
        gradient = (2 * X * E).sum()
        w = w - (eta * gradient)
        t +=1
    return w

# %%
a = regr(X2b,Y2_train,n_iter=25,verbose=True)
print("w= ",a)
# Out:
# Objectif: 25.120934633690382
# Objectif: 25.101237703862918
# Objectif: 25.082532342043212
# Objectif: 25.064299710814193
# Objectif: 25.046509557174353
# Objectif: 25.029150717199478
# Objectif: 25.012212986301545
# Objectif: 24.995686414988384
# Objectif: 24.979561277389365
# Objectif: 24.963828065810517
# Objectif: 24.94847748635279
# Objectif: 24.93350045463006
# Objectif: 24.91888809155008
# Objectif: 24.90463171915712
# Objectif: 24.89072285653657
# Objectif: 24.877153215781586
# Objectif: 24.8639146980218
# Objectif: 24.85099938951427
# Objectif: 24.838399557796446
# Objectif: 24.826107647901228
# Objectif: 24.814116278633875
# Objectif: 24.802418238910576
# Objectif: 24.791006484158533
# Objectif: 24.779874132777152
# Objectif: 24.769014462660135
# w=  [0.65999833 0.10096875]

# %%
a = regr(X1,y1,n_iter=25,verbose=True)
print("w= ",a)
# Out:
# Objectif: 33.379177541100034
# Objectif: 32.04014546859138
# Objectif: 31.149540353499244
# Objectif: 30.563688963309875
# Objectif: 30.18131392212686
# Objectif: 29.933082956983412
# Objectif: 29.7725169008025
# Objectif: 29.668903964691406
# Objectif: 29.602147260211947
# Objectif: 29.559180365863753
# Objectif: 29.53154361900606
# Objectif: 29.51377494098057
# Objectif: 29.50235393851349
# Objectif: 29.49501426635415
# Objectif: 29.490297984255086
# Objectif: 29.487267645566337
# Objectif: 29.48532066247435
# Objectif: 29.48406976969032
# Objectif: 29.483266114831014
# Objectif: 29.482749801126122
# Objectif: 29.482418094417397
# Objectif: 29.48220498991563
# Objectif: 29.48206808168479
# Objectif: 29.48198012566447
# Objectif: 29.481923618828358
# w=  [0.76278835]

# %% [markdown]
# Le réglage du pas de gradient peut être complexe...

# %% [markdown]
# **Question** Vérifier que l'algorithme ne converge pas vers une solution si le pas est trop grand

# %%
a = regr(X2b,Y2_train,10,n_iter=25,verbose=True)
print("w= ",a)
# Out:
# Objectif: 28.86419387505565
# Objectif: 2351212.441735649
# Objectif: 377875227040.19275
# Objectif: 6.073115695921643e+16
# Objectif: 9.760558976316626e+21
# Objectif: 1.5686925179808016e+27
# Objectif: 2.5211632058572815e+32
# Objectif: 4.051950167232429e+37
# Objectif: 6.512192514784904e+42
# Objectif: 1.046623220901716e+48
# Objectif: 1.682106547132481e+53
# Objectif: 2.703439384297458e+58
# Objectif: 4.344899862038883e+63
# Objectif: 6.983013904730608e+68
# Objectif: 1.1222924518858477e+74
# Objectif: 1.8037202341909686e+79
# Objectif: 2.898893846931832e+84
# Objectif: 4.65902936413448e+89
# Objectif: 7.48787494886761e+94
# Objectif: 1.2034324505764326e+100
# Objectif: 1.9341264016694296e+105
# Objectif: 3.10847936321054e+110
# Objectif: 4.995869940643781e+115
# Objectif: 8.029236661249673e+120
# Objectif: 1.2904387449695724e+126
# w=  [2.22796325e+129 6.23526272e+128]

# %% [markdown]
# **Question** Une petite heuristique est de vérifier si l'objectif décroit. Si tel est le cas on peut augmenter de 10% le pas de gradient et sinon on le divise par 10.

# %%
def regr_tuned(X, y, eta=0.0001, n_iter=100, verbose=False):
    """On règle eta en contrôlant la valeur de l'objectif"""
    w = np.random.random(X.shape[1])
    t = 0
    last_obj = np.linalg.norm(X@w - y)
    while (t < n_iter):
        E = X@w - y
        objectif = np.linalg.norm(E)

        if (last_obj > objectif):
            eta *= 10 
        else:
            eta /=10

        last_obj = objectif

        if verbose:
           print("Objectif: ",objectif)
        gradient = (2 * (X * erreur)).sum(axis=0)
        w = w - (eta * gradient)
        t +=1
    return

# %%
regr(X1,y1,n_iter=25,verbose=True)
# Out:
# Objectif: 29.86981658311772
# Objectif: 29.731667844151726
# Objectif: 29.642575523925263
# Objectif: 29.585197272097936
# Objectif: 29.548276253007895
# Objectif: 29.524532257170407
# Objectif: 29.509268022254236
# Objectif: 29.499457459849264
# Objectif: 29.49315301454918
# Objectif: 29.48910205898985
# Objectif: 29.48649925879601
# Objectif: 29.484826987754005
# Objectif: 29.483752599494487
# Objectif: 29.483062346011568
# Objectif: 29.482618889217544
# Objectif: 29.482333990146106
# Objectif: 29.482150957382764
# Objectif: 29.482033368732047
# Objectif: 29.48195782452172
# Objectif: 29.481909291597873
# Objectif: 29.481878111936123
# Objectif: 29.4818580807746
# Objectif: 29.481845211895184
# Objectif: 29.481836944375384
# Objectif: 29.48183163296694
# array([0.76375361])
