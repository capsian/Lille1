# %% [markdown]
# # TD Deep Q-Network

# %% [markdown]
# # Tutorial - Deep Q-Learning
#
# Deep Q-Learning uses a neural network to approximate $Q$ functions. Hence, we usually refer to this algorithm as DQN (for *deep Q network*).
#
# The parameters of the neural network are denoted by $\theta$.
# *   As input, the network takes a state $s$,
# *   As output, the network returns $Q_\theta [a | s] = Q_\theta (s,a) = Q(s, a, \theta)$, the value of each action $a$ in state $s$, according to the parameters $\theta$.
#
#
# The goal of Deep Q-Learning is to learn the parameters $\theta$ so that $Q(s, a, \theta)$ approximates well the optimal $Q$-function $Q^*(s, a) \simeq Q_{\theta^*} (s,a)$.
#
# In addition to the network with parameters $\theta$, the algorithm keeps another network with the same architecture and parameters $\theta^-$, called **target network**.
#
# The algorithm works as follows:
#
# 1.   At each time $t$, the agent is in state $s_t$ and has observed the transitions $(s_i, a_i, r_i, s_i')_{i=1}^{t-1}$, which are stored in a **replay buffer**.
#
# 2.  Choose action $a_t = \arg\max_a Q_\theta(s_t, a)$ with probability $1-\varepsilon_t$, and $a_t$=random action with probability $\varepsilon_t$.
#
# 3. Take action $a_t$, observe reward $r_t$ and next state $s_t'$.
#
# 4. Add transition $(s_t, a_t, r_t, s_t')$ to the **replay buffer**.
#
# 4.  Sample a minibatch $\mathcal{B}$ containing $B$ transitions from the replay buffer. Using this minibatch, we define the loss:
#
# $$
# L(\theta) = \sum_{(s_i, a_i, r_i, s_i') \in \mathcal{B}}
# \left[
# Q(s_i, a_i, \theta) -  y_i
# \right]^2
# $$
# where the $y_i$ are the **targets** computed with the **target network** $\theta^-$:
#
# $$
# y_i = r_i + \gamma \max_{a'} Q(s_i', a', \theta^-).
# $$
#
# 5. Update the parameters $\theta$ to minimize the loss, e.g., with gradient descent (**keeping $\theta^-$ fixed**):
# $$
# \theta \gets \theta - \eta \nabla_\theta L(\theta)
# $$
# where $\eta$ is the optimization learning rate.
#
# 6. Every $N$ transitions ($t\mod N$ = 0), update target parameters: $\theta^- \gets \theta$.
#
# 7. $t \gets t+1$. Stop if $t = T$, otherwise go to step 2.

# %%
# Imports
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import random
from copy import deepcopy
import gym
from gym.wrappers import Monitor

import matplotlib.pyplot as plt

# from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
from IPython.display import clear_output
from pathlib import Path
import base64

import pandas as pd

# %%
print(f"python --version = {sys.version}")
print(f"torch.__version__ = {torch.__version__}")
print(f"np.__version__ = {np.__version__}")
print(f"gym.__version__ = {gym.__version__}")
# Out:
# python --version = 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# torch.__version__ = 1.9.0+cu111
# np.__version__ = 1.21.4
# gym.__version__ = 0.21.0

# %% [markdown]
# ## Torch 101
#
# >"The torch package contains data structures for multi-dimensional tensors and defines mathematical operations over these tensors. Additionally, it provides many utilities for efficient serializing of Tensors and arbitrary types, and other useful utilities.
# [...] provides classes and functions implementing automatic differentiation of arbitrary scalar valued functions."
# [PyTorch](https://pytorch.org/docs/stable/index.html)

# %% [markdown]
# ### Variable types

# %%
# Very similar syntax to numpy.
zero_torch = torch.zeros((3, 2))

print('zero_torch is of type {:s}'.format(str(type(zero_torch))))

# Torch -> Numpy: simply call the numpy() method.
zero_np = np.zeros((3, 2))
assert (zero_torch.numpy() == zero_np).all()

# Numpy -> Torch: simply call the corresponding function on the np.array.
zero_torch_float = torch.FloatTensor(zero_np)
print('\nFloat:\n', zero_torch_float)
zero_torch_int = torch.LongTensor(zero_np)
print('Int:\n', zero_torch_int)
zero_torch_bool = torch.BoolTensor(zero_np)
print('Bool:\n', zero_torch_bool)

# Reshape
print('\nView new shape...', zero_torch.view(1, 6))
# Note that print(zero_torch.reshape(1, 6)) would work too.
# The difference is in how memory is handled (view imposes contiguity).

# Algebra
a = torch.randn((3, 2))
b = torch.randn((3, 2))
print('\nAlgebraic operations are overloaded:\n', a, '\n+\n', b, '\n=\n', a+b )

# More generally, torch shares the syntax of many attributes and functions with Numpy.
# Out:
# zero_torch is of type <class 'torch.Tensor'>
#
# Float:
#  tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# Int:
#  tensor([[0, 0],
#         [0, 0],
#         [0, 0]])
# Bool:
#  tensor([[False, False],
#         [False, False],
#         [False, False]])
#
# View new shape... tensor([[0., 0., 0., 0., 0., 0.]])
#
# Algebraic operations are overloaded:
#  tensor([[ 0.7060, -0.5300],
#         [-0.8470, -0.1996],
#         [ 0.2130,  0.0380]])
# +
#  tensor([[-0.3254,  0.8934],
#         [-1.1127,  0.1728],
#         [ 0.4802, -0.5758]])
# =
#  tensor([[ 0.3806,  0.3633],
#         [-1.9597, -0.0269],
#         [ 0.6932, -0.5378]])

# %% [markdown]
# ### Gradient management

# %%
# torch.Tensor is a similar yet more complicated data structure than np.array.
# It is basically a static array of number but may also contain an overlay to 
# handle automatic differentiation (i.e keeping track of the gradient and which 
# tensors depend on which).
# To access the static array embedded in a tensor, simply call the detach() method
print(zero_torch.detach())

# When inside a function performing automatic differentiation (basically when training 
# a neural network), never use detach() otherwise meta information regarding gradients
# will be lost, effectively freezing the variable and preventing backprop for it. 
# However when returning the result of training, do use detach() to save memory 
# (the naked tensor data uses much less memory than the full-blown tensor with gradient
# management, and is much less prone to mistake such as bad copy and memory leak).

# We will solve theta * x = y in theta for x=1 and y=2
x = torch.ones(1)
y = 2 * torch.ones(1)

# Actually by default torch does not add the gradient management overlay
# when declaring tensors like this. To force it, add requires_grad=True.
theta = torch.randn(1, requires_grad=True)

# Optimisation routine
# (Adam is a sophisticated variant of SGD, with adaptive step).
optimizer = optim.Adam(params=[theta], lr=0.1)

# Loss function
print('Initial guess:', theta.detach())

for _ in range(100):
    # By default, torch accumulates gradients in memory.
    # To obtain the desired gradient descent beahviour,
    # just clean the cached gradients using the following line:
    optimizer.zero_grad()
    
    # Quadratic loss (* and ** are overloaded so that torch
    # knows how to differentiate them)
    loss = (y - theta * x) ** 2
    
    # Apply the chain rule to automatically compute gradients
    # for all relevant tensors.
    loss.backward()
    
    # Run one step of optimisation routine.
    optimizer.step()
    
print('Final estimate:', theta.detach())
print('The final estimate should be close to', y)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# Initial guess: tensor([0.8606])
# Final estimate: tensor([2.0046])
# The final estimate should be close to tensor([2.])

# %% [markdown]
# ## Setting the environment
#
# ### 1 - Define the GLOBAL parameters

# %%
# Environment
env = gym.make("CartPole-v0")

# Discount factor
GAMMA = 0.99

# Batch size
BATCH_SIZE = 256
# Capacity of the replay buffer
BUFFER_CAPACITY = 16384 # 10000
# Update target net every ... episodes
UPDATE_TARGET_EVERY = 32 # 20

# Initial value of epsilon
EPSILON_START = 1.0
# Parameter to decrease epsilon
DECREASE_EPSILON = 200
# Minimum value of epislon
EPSILON_MIN = 0.05

# Number of training episodes
N_EPISODES = 200

# Learning rate
LEARNING_RATE = 0.1

# %% [markdown]
# ### 2 - Replay buffer

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, state, action, reward, done, next_state):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = (state, action, reward, done, next_state)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.choices(self.memory, k=batch_size)

    def __len__(self):
        return len(self.memory)

# create instance of replay buffer
replay_buffer = ReplayBuffer(BUFFER_CAPACITY)

# %% [markdown]
# ### 3 - Neural Network

# %%
class Net(nn.Module):
    """
    Basic neural net.
    """
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ### 3.5 - Loss function and optimizer

# %%
# create network and target network
hidden_size = 128
obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

q_net = Net(obs_size, hidden_size, n_actions)
target_net = Net(obs_size, hidden_size, n_actions)

# objective and optimizer
objective = nn.MSELoss()
optimizer = optim.Adam(params=q_net.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### Question 0 (to do at home, not during the live session)
#
# With your own word, explain the intuition behind DQN. Recall the main parts of the aformentionned algorithm.

# %% [markdown]
# - Nous allons utiliser un réseau de neurones pour prédire la fonction Q.
# - Nous allons utiliser deux réseau de neurones ou l'un sera mis à jour périodiquement grâce à l'autre !

# %% [markdown]
# ## Implementing the DQN

# %%
def get_q(states):
    """
    Compute Q function for a list of states
    """
    with torch.no_grad():
        states_v = torch.FloatTensor([states])
        output = q_net.forward(states_v).detach().numpy()  # shape (1, len(states), n_actions)
    return output[0, :, :]  # shape (len(states), n_actions)

# %% [markdown]
# #### Question 1
#
# Implement the `choose_action` function.

# %%
def choose_action(state, epsilon):
    """
    ** TO BE IMPLEMENTED **
    
    Return action according to an epsilon-greedy exploration policy
    """
    
    # Determine next action - epsilon greedy strategy
    if np.random.random() < 1 - epsilon:        
        q = get_q([state])[0]
        action = np.argmax(q)     
    else:
        action = np.random.randint(0, n_actions)
            
    return action

# %% [markdown]
# #### Question 2
#
# Implement the `eval_dqn` function.

# %%
def eval_dqn(n_sim=5):
    """
    ** TO BE IMPLEMENTED **
    
    Monte Carlo evaluation of DQN agent.

    Repeat n_sim times:
        * Run the DQN policy until the environment reaches a terminal state (= one episode)
        * Compute the sum of rewards in this episode
        * Store the sum of rewards in the episode_rewards array.
    """
    env_copy = deepcopy(env)
    episode_rewards = np.zeros(n_sim)
    
    for i in range(n_sim):
        next_state = env_copy.reset()
        
        done = False
        tmp_rewards = []
                
        while not done:
            action = choose_action(next_state, 0)
            
            next_state, reward, done, _ = env_copy.step(action)
            tmp_rewards += [reward]
        
        # print(i, len(tmp_rewards), tmp_rewards)
        episode_rewards[i] = np.sum(tmp_rewards)
    
    return episode_rewards

# %% [markdown]
# #### Question 3
#
# Implement the `update` function

# %%
def update(state, action, reward, next_state, done):
    """
    ** TO BE COMPLETED **
    """
    
    # add data to replay buffer
    # if done:
    #     next_state = None
    replay_buffer.push(state, action, reward, done, next_state)
    
    if len(replay_buffer) < BATCH_SIZE:
        return np.inf
    
    # get batch
    transitions = replay_buffer.sample(BATCH_SIZE)
        
    current_obs = np.asarray([t[0] for t in transitions])
    actions = np.asarray([t[1] for t in transitions])
    rewards = np.asarray([t[2] for t in transitions])
    dones = np.asarray([t[3] for t in transitions])
    new_obs = np.asarray([t[4] for t in transitions])
    
    current_obs_t = torch.as_tensor(current_obs,dtype=torch.float32)
    actions_t = torch.as_tensor(actions,dtype=torch.int64).unsqueeze(-1)
    rewards_t = torch.as_tensor(rewards,dtype=torch.float32).unsqueeze(-1)
    dones_t = torch.as_tensor(dones,dtype=torch.float32).unsqueeze(-1)
    new_obs_t = torch.as_tensor(new_obs,dtype=torch.float32)
   
    #cumputing targets
    q_values = q_net(current_obs_t)
    action_q_values = torch.gather(input=q_values,dim=1,index=actions_t)
    
    target_q_values = target_net(new_obs_t)
    max_target_q_values = target_q_values.max(dim=1,keepdim=True)[0].detach()

    targets = rewards_t + (GAMMA *(1-dones_t)*max_target_q_values)
    
    #compute loss
    objective = nn.MSELoss()
    loss = objective(action_q_values,targets)

    # Optimize the model - UNCOMMENT!
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    return loss.detach().numpy()

# %% [markdown]
# #### Question 4
# Train a DQN on the `env` environment.
# *Hint* The mean reward after training should be close to 200.

# %%
EVAL_EVERY = 5
REWARD_THRESHOLD = 199

def train():
    state = env.reset()
    epsilon = EPSILON_START
    ep = 0
    total_time = 0
    losses = []
    ep_loss = []
    while ep < N_EPISODES:
        action = choose_action(state, epsilon)

        # take action and update replay buffer and networks
        next_state, reward, done, _ = env.step(action)
        loss = update(state, action, reward, next_state, done)
        ep_loss += [float(loss)]

        # update state
        state = next_state

        # end episode if done
        if done:
            losses += [np.mean(ep_loss)]
            
            state = env.reset()
            ep   += 1
            if ( (ep+1)% EVAL_EVERY == 0):
                rewards = eval_dqn()
                print("episode =", ep+1, ", reward = ", np.mean(rewards), "mean losses:", np.mean(ep_loss))
                if np.mean(rewards) >= REWARD_THRESHOLD:
                    break
                    
            ep_loss = []

            # update target network
            if ep % UPDATE_TARGET_EVERY == 0:
                print("train: ep:", ep+1, "update target_net !")
                target_net.load_state_dict(q_net.state_dict())
            # decrease epsilon
            epsilon = EPSILON_MIN + (EPSILON_START - EPSILON_MIN) * \
                            np.exp(-1. * ep / DECREASE_EPSILON )    

        total_time += 1
    
    return ep, losses

# Run the training loop
nb_ep, losses = train()

# Evaluate the final policy
rewards = eval_dqn(20)
print("mean reward after training = ", np.mean(rewards))
# Out:
# episode = 5 , reward =  106.2 mean losses: 0.12920792400836945
# episode = 10 , reward =  107.0 mean losses: 0.12280950779941949
# episode = 15 , reward =  106.0 mean losses: 0.13012975283587971
# episode = 20 , reward =  99.0 mean losses: 0.12047684388725381
# episode = 25 , reward =  108.2 mean losses: 0.15360554883425886
# episode = 30 , reward =  102.8 mean losses: 0.11376320151612163
# train: ep: 33 update target_net !
# episode = 35 , reward =  64.6 mean losses: 0.20289546936750413
# episode = 40 , reward =  69.0 mean losses: 0.18566166299084821
# episode = 45 , reward =  108.0 mean losses: 0.1453569158911705
# episode = 50 , reward =  109.0 mean losses: 0.15629868056529608
# episode = 55 , reward =  108.0 mean losses: 0.18127092153861604
# episode = 60 , reward =  105.8 mean losses: 0.18882700898077176
# episode = 65 , reward =  105.8 mean losses: 0.1645389966228429
# train: ep: 65 update target_net !
# episode = 70 , reward =  110.8 mean losses: 0.24640649308760962
# episode = 75 , reward =  109.0 mean losses: 0.28386460552955495
# episode = 80 , reward =  107.4 mean losses: 0.24039237514922493
# episode = 85 , reward =  106.4 mean losses: 0.2568272183600225
# episode = 90 , reward =  111.2 mean losses: 0.2668568590736907
# episode = 95 , reward =  106.4 mean losses: 0.23890881516884283
# train: ep: 97 update target_net !
# episode = 100 , reward =  107.6 mean losses: 0.3146102965781183
# episode = 105 , reward =  107.8 mean losses: 0.3029110756787387
# episode = 110 , reward =  128.8 mean losses: 0.26764461930309025
# episode = 115 , reward =  109.8 mean losses: 0.2943333414969621
# episode = 120 , reward =  106.8 mean losses: 0.34025351277419497
# episode = 125 , reward =  103.6 mean losses: 0.26584890762380525
# train: ep: 129 update target_net !
# episode = 130 , reward =  107.4 mean losses: 0.4096529457880103
# episode = 135 , reward =  106.4 mean losses: 0.41946686307589215
# episode = 140 , reward =  108.4 mean losses: 0.404762437822772
# episode = 145 , reward =  105.6 mean losses: 0.4381148524062578
# episode = 150 , reward =  107.6 mean losses: 0.4225691951373044
# episode = 155 , reward =  106.2 mean losses: 0.4145515088153922
# episode = 160 , reward =  108.4 mean losses: 0.38321001465831483
# train: ep: 161 update target_net !
# episode = 165 , reward =  116.6 mean losses: 0.4761245014206056
# episode = 170 , reward =  104.4 mean losses: 0.48986212565348697
# episode = 175 , reward =  105.8 mean losses: 0.5149794922665109
# episode = 180 , reward =  109.0 mean losses: 0.4700621054149591
# episode = 185 , reward =  107.6 mean losses: 0.5473296745618185
# episode = 190 , reward =  150.4 mean losses: 0.48624535128474233
# train: ep: 193 update target_net !
# episode = 195 , reward =  122.6 mean losses: 0.5012950051043715
# episode = 200 , reward =  97.8 mean losses: 0.5258181591828665
# mean reward after training =  103.2

# %%
plt.plot(losses)

# %% [markdown]
# #### Question 5
#
# Experiment the policy network.
#
# (Showing a video with a jupyter notebook, you may try this cell with Chrome/Chromium instead of Firefox. Otherwise, you may skip this question.)

# %%
def show_video():
    html = []
    for mp4 in Path("videos").glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append('''<video alt="{}" autoplay 
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>'''.format(mp4, video_b64.decode('ascii')))
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))
    
env = Monitor(env, './videos', force=True, video_callable=lambda episode: True)

for episode in range(1):
    done = False
    state = env.reset()
    while not done:
        action = choose_action(state, 0.0)
        state, reward, done, info = env.step(action)
env.close()
# show_video()

# %% [markdown]
# ### Experiments: Do It Yourself

# %% [markdown]
# Remember the set of global parameters:
# ```
# # Environment
# env = gym.make("CartPole-v0")
#
# # Discount factor
# GAMMA = 0.99
#
# # Batch size
# BATCH_SIZE = 256
# # Capacity of the replay buffer
# BUFFER_CAPACITY = 16384 # 10000
# # Update target net every ... episodes
# UPDATE_TARGET_EVERY = 32 # 20
#
# # Initial value of epsilon
# EPSILON_START = 1.0
# # Parameter to decrease epsilon
# DECREASE_EPSILON = 200
# # Minimum value of epislon
# EPSILON_MIN = 0.05
#
# # Number of training episodes
# N_EPISODES = 200
#
# # Learning rate
# LEARNING_RATE = 0.1
# ```

# %%
BUFFER_CAPACITY_LIST = [1000, 5000, 10000, 15000, 18000, 20000, 30000]
UPDATE_TARGET_EVERY_LIST = [10, 20, 30, 40, 50, 100, 1000]
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# %% [markdown]
# #### Question 6
#
# Craft an experiment and study the influence of the `BUFFER_CAPACITY` on the learning process (speed of *convergence*, training curves...)

# %%
fig1 = plt.figure(figsize=(20,20))
ax1 = plt.axes()

fig2 = plt.figure(figsize=(20,20))
ax2 = plt.axes()

df_res = pd.DataFrame(index=['mean_reward', 'std_rewards', 'nb_episodes'])

c_i = 0
UPDATE_TARGET_EVERY = 32
for BUFFER_CAPACITY in BUFFER_CAPACITY_LIST:
    print("BUFFER_CAPACITY:", BUFFER_CAPACITY)
    # create instance of replay buffer
    replay_buffer = ReplayBuffer(BUFFER_CAPACITY)
    
    # create network and target network
    hidden_size = 128
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    q_net = Net(obs_size, hidden_size, n_actions)
    target_net = Net(obs_size, hidden_size, n_actions)
    
    # objective and optimizer
    objective = nn.MSELoss()
    optimizer = optim.Adam(params=q_net.parameters(), lr=LEARNING_RATE)
    
    # Run the training loop
    nb_ep, losses = train()

    # Evaluate the final policy
    rewards = eval_dqn(20)
    print("")
    print("mean loss during training = ", np.mean(losses))
    print("mean reward after training = ", np.mean(rewards), 'std:', np.std(rewards))
    print("=================================================")
    print()
    
    df_res[str(BUFFER_CAPACITY)] = [np.mean(rewards), np.std(rewards), nb_ep]
    
    ax1.plot(rewards, label='reward_BUFFER_CAPACITY_' + str(BUFFER_CAPACITY), c=colors[c_i])
    ax2.plot(losses, label='losses_BUFFER_CAPACITY_' + str(BUFFER_CAPACITY), c=colors[c_i], linestyle='-')
    c_i += 1

fig1.legend()    
fig1.show()

fig2.legend()    
fig2.show()
# Out:
# BUFFER_CAPACITY: 1000
# episode = 5 , reward =  15.2 mean losses: inf
# episode = 10 , reward =  14.0 mean losses: inf
# episode = 15 , reward =  23.0 mean losses: 0.31039738468825817
# episode = 20 , reward =  9.2 mean losses: 0.0013530220137909054
# episode = 25 , reward =  9.6 mean losses: 0.0013607414002763107
# episode = 30 , reward =  9.6 mean losses: 0.0008503011715794472
# train: ep: 33 update target_net !
# episode = 35 , reward =  9.0 mean losses: 0.10359466820955276
# episode = 40 , reward =  10.6 mean losses: 0.026936157420277596
# episode = 45 , reward =  9.6 mean losses: 0.019416699461914873
# episode = 50 , reward =  9.4 mean losses: 0.022145168234904606
# episode = 55 , reward =  9.6 mean losses: 0.014641913662975034
# episode = 60 , reward =  9.6 mean losses: 0.01874212622642517
# episode = 65 , reward =  9.2 mean losses: 0.013961708856125672
# train: ep: 65 update target_net !
# episode = 70 , reward =  10.2 mean losses: 0.018978680757915273
# episode = 75 , reward =  9.8 mean losses: 0.02554003402058567
# episode = 80 , reward =  9.4 mean losses: 0.018380933958623145
# episode = 85 , reward =  9.6 mean losses: 0.014379425294464454
# episode = 90 , reward =  9.4 mean losses: 0.020947916666045785
# episode = 95 , reward =  10.6 mean losses: 0.02044822499155998
# train: ep: 97 update target_net !
# episode = 100 , reward =  10.0 mean losses: 0.041063784518175654
# episode = 105 , reward =  9.6 mean losses: 0.043106713818143245
# episode = 110 , reward =  10.0 mean losses: 0.030034980197486124
# episode = 115 , reward =  10.0 mean losses: 0.0300872465595603
# episode = 120 , reward =  10.4 mean losses: 0.033150326603880294
# episode = 125 , reward =  10.4 mean losses: 0.039841969243504784
# train: ep: 129 update target_net !
# episode = 130 , reward =  20.2 mean losses: 0.23448736504429862
# episode = 135 , reward =  21.8 mean losses: 0.0865186964472135
# episode = 140 , reward =  10.6 mean losses: 0.07208883370223798
# episode = 145 , reward =  13.8 mean losses: 0.0686727413178786
# episode = 150 , reward =  11.0 mean losses: 0.0548782649760445
# episode = 155 , reward =  13.8 mean losses: 0.06328921419169221
# episode = 160 , reward =  10.4 mean losses: 0.07177352118823263
# train: ep: 161 update target_net !
# episode = 165 , reward =  145.2 mean losses: 0.09565864601417591
# episode = 170 , reward =  9.0 mean losses: 0.1206099668092895
# episode = 175 , reward =  48.0 mean losses: 0.04965311701276472
# episode = 180 , reward =  48.4 mean losses: 0.06021212929008919
# episode = 185 , reward =  48.8 mean losses: 0.09342867753176547
# episode = 190 , reward =  18.4 mean losses: 0.0987922093126832
# train: ep: 193 update target_net !
# episode = 195 , reward =  92.8 mean losses: 0.17873389579887902
# episode = 200 , reward =  77.6 mean losses: 0.1473513099492765
#
# mean loss during training =  inf
# mean reward after training =  75.5 std: 3.556683848755748
# =================================================
#
# BUFFER_CAPACITY: 5000
# episode = 5 , reward =  9.2 mean losses: inf
# episode = 10 , reward =  8.8 mean losses: inf
# episode = 15 , reward =  9.0 mean losses: 0.0025466093447411783
# episode = 20 , reward =  10.4 mean losses: 0.0002704450861558378
# episode = 25 , reward =  8.8 mean losses: 0.00025372454001626465
# episode = 30 , reward =  9.6 mean losses: 0.00016439913020736572
# train: ep: 33 update target_net !
# episode = 35 , reward =  9.2 mean losses: 0.0723850133900459
# episode = 40 , reward =  11.2 mean losses: 0.025815754383802413
# episode = 45 , reward =  11.4 mean losses: 0.017005893646886473
# episode = 50 , reward =  10.2 mean losses: 0.015775817174774904
# episode = 55 , reward =  9.2 mean losses: 0.010919619208345046
# episode = 60 , reward =  9.4 mean losses: 0.009303551536567253
# episode = 65 , reward =  10.0 mean losses: 0.014634786946017568
# train: ep: 65 update target_net !
# episode = 70 , reward =  9.4 mean losses: 0.03306070063263178
# episode = 75 , reward =  10.4 mean losses: 0.040052373046902096
# episode = 80 , reward =  9.6 mean losses: 0.03661415372043848
# episode = 85 , reward =  9.2 mean losses: 0.037680901431789
# episode = 90 , reward =  10.2 mean losses: 0.0250913030044599
# episode = 95 , reward =  10.2 mean losses: 0.039288056548684835
# train: ep: 97 update target_net !
# episode = 100 , reward =  13.2 mean losses: 0.03557502074788014
# episode = 105 , reward =  10.2 mean losses: 0.027162018014738956
# episode = 110 , reward =  14.8 mean losses: 0.02523758200307687
# episode = 115 , reward =  11.4 mean losses: 0.030563257401809096
# episode = 120 , reward =  10.2 mean losses: 0.02746912844192523
# episode = 125 , reward =  10.0 mean losses: 0.03166156568165336
# train: ep: 129 update target_net !
# episode = 130 , reward =  55.0 mean losses: 0.1226448193192482
# episode = 135 , reward =  20.6 mean losses: 0.049133624458177524
# episode = 140 , reward =  20.6 mean losses: 0.04662053787002438
# episode = 145 , reward =  49.2 mean losses: 0.04499754793941975
# episode = 150 , reward =  13.6 mean losses: 0.046908622099594635
# episode = 155 , reward =  32.6 mean losses: 0.050640465425593514
# episode = 160 , reward =  9.2 mean losses: 0.06793788035533257
# train: ep: 161 update target_net !
# episode = 165 , reward =  74.8 mean losses: 0.08730766240220804
# episode = 170 , reward =  40.0 mean losses: 0.09330156596288794
# episode = 175 , reward =  57.0 mean losses: 0.09237354926087639
# episode = 180 , reward =  36.2 mean losses: 0.0736435018479824
# episode = 185 , reward =  79.4 mean losses: 0.08482901953781645
# episode = 190 , reward =  19.8 mean losses: 0.0918512147935954
# train: ep: 193 update target_net !
# episode = 195 , reward =  106.2 mean losses: 0.17585503144396675
# episode = 200 , reward =  24.4 mean losses: 0.1269017834502917
#
# mean loss during training =  inf
# mean reward after training =  49.55 std: 18.744265789835566
# =================================================
#
# BUFFER_CAPACITY: 10000
# episode = 5 , reward =  114.0 mean losses: inf
# episode = 10 , reward =  113.0 mean losses: inf
# episode = 15 , reward =  8.8 mean losses: inf
# episode = 20 , reward =  9.4 mean losses: 0.01063238297972609
# episode = 25 , reward =  9.2 mean losses: 0.005877977004274726
# episode = 30 , reward =  9.2 mean losses: 0.003240180529692039
# train: ep: 33 update target_net !
# episode = 35 , reward =  9.6 mean losses: 0.06610445967978901
# episode = 40 , reward =  8.8 mean losses: 0.016241962400575478
# episode = 45 , reward =  9.0 mean losses: 0.012622661673678802
# episode = 50 , reward =  9.4 mean losses: 0.014051102298813371
# episode = 55 , reward =  10.2 mean losses: 0.014758892240934074
# episode = 60 , reward =  10.0 mean losses: 0.012233898043632507
# episode = 65 , reward =  9.6 mean losses: 0.013756962073966861
# train: ep: 65 update target_net !
# episode = 70 , reward =  10.4 mean losses: 0.018065817869053438
# episode = 75 , reward =  10.4 mean losses: 0.016756183522589067
# episode = 80 , reward =  10.6 mean losses: 0.015994343763360612
# episode = 85 , reward =  10.2 mean losses: 0.020014763132415035
# episode = 90 , reward =  10.0 mean losses: 0.02168469926199088
# episode = 95 , reward =  13.0 mean losses: 0.015444525310562717
# train: ep: 97 update target_net !
# episode = 100 , reward =  31.6 mean losses: 0.0343033367395401
# episode = 105 , reward =  50.8 mean losses: 0.03107546686249621
# episode = 110 , reward =  10.4 mean losses: 0.02757278977272411
# episode = 115 , reward =  27.8 mean losses: 0.026049065847127212
# episode = 120 , reward =  10.4 mean losses: 0.028617928070681437
# episode = 125 , reward =  19.4 mean losses: 0.030249120201915503
# train: ep: 129 update target_net !
# episode = 130 , reward =  9.8 mean losses: 0.2994800681869189
# episode = 135 , reward =  42.4 mean losses: 0.05751264444552362
# episode = 140 , reward =  32.4 mean losses: 0.051907242810789574
# episode = 145 , reward =  11.6 mean losses: 0.04731452964246273
# episode = 150 , reward =  60.4 mean losses: 0.04038452352397144
# episode = 155 , reward =  11.8 mean losses: 0.04579626074568792
# episode = 160 , reward =  11.0 mean losses: 0.04670541547238827
# train: ep: 161 update target_net !
# episode = 165 , reward =  29.6 mean losses: 0.07923190987535886
# episode = 170 , reward =  43.0 mean losses: 0.06997937315072005
# episode = 175 , reward =  21.8 mean losses: 0.073573703267451
# episode = 180 , reward =  61.2 mean losses: 0.06640590776999791
# episode = 185 , reward =  62.6 mean losses: 0.05269919314350073
# episode = 190 , reward =  23.6 mean losses: 0.05801833287945816
# train: ep: 193 update target_net !
# episode = 195 , reward =  33.6 mean losses: 0.17562292681799996
# episode = 200 , reward =  53.8 mean losses: 0.09955233844731926
#
# mean loss during training =  inf
# mean reward after training =  84.1 std: 30.232267529909166
# =================================================
#
# BUFFER_CAPACITY: 15000
# episode = 5 , reward =  9.0 mean losses: inf
# episode = 10 , reward =  9.6 mean losses: inf
# episode = 15 , reward =  19.0 mean losses: 0.0024028731806373053
# episode = 20 , reward =  22.2 mean losses: 0.0007350191648583859
# episode = 25 , reward =  18.6 mean losses: 0.0005802174035290426
# episode = 30 , reward =  22.0 mean losses: 0.0005387887871447241
# train: ep: 33 update target_net !
# episode = 35 , reward =  8.6 mean losses: 0.02934164557682008
# episode = 40 , reward =  17.2 mean losses: 0.016625043749809266
# episode = 45 , reward =  14.6 mean losses: 0.013557007758035547
# episode = 50 , reward =  11.0 mean losses: 0.013444845693121696
# episode = 55 , reward =  9.2 mean losses: 0.033912721648812295
# episode = 60 , reward =  32.4 mean losses: 0.016309203297298933
# episode = 65 , reward =  12.8 mean losses: 0.014201542256738652
# train: ep: 65 update target_net !
# episode = 70 , reward =  34.2 mean losses: 0.02418183130570329
# episode = 75 , reward =  30.0 mean losses: 0.018546020922561485
# episode = 80 , reward =  9.2 mean losses: 0.025014623440802096
# episode = 85 , reward =  9.4 mean losses: 0.018430892284959553
# episode = 90 , reward =  22.4 mean losses: 0.020186592417303473
# episode = 95 , reward =  14.4 mean losses: 0.0197447636542288
# train: ep: 97 update target_net !
# episode = 100 , reward =  35.0 mean losses: 0.03725123978578127
# episode = 105 , reward =  22.4 mean losses: 0.032959300590058166
# episode = 110 , reward =  11.0 mean losses: 0.0348225576145684
# episode = 115 , reward =  51.0 mean losses: 0.032681302441393625
# episode = 120 , reward =  61.8 mean losses: 0.03970862328466298
# episode = 125 , reward =  9.0 mean losses: 0.03747141979296099
# train: ep: 129 update target_net !
# episode = 130 , reward =  10.8 mean losses: 0.3602507434785366
# episode = 135 , reward =  17.6 mean losses: 0.06987620145082474
# episode = 140 , reward =  10.0 mean losses: 0.06716441805991862
# episode = 145 , reward =  79.4 mean losses: 0.07032258013884227
# episode = 150 , reward =  75.2 mean losses: 0.07781101908625626
# episode = 155 , reward =  10.0 mean losses: 0.06088551552966237
# episode = 160 , reward =  36.4 mean losses: 0.06580800337618903
# train: ep: 161 update target_net !
# episode = 165 , reward =  65.4 mean losses: 0.10220399467895429
# episode = 170 , reward =  24.2 mean losses: 0.1128699871662416
# episode = 175 , reward =  52.2 mean losses: 0.11128067996885095
# episode = 180 , reward =  17.0 mean losses: 0.1171600461198852
# episode = 185 , reward =  20.2 mean losses: 0.13949545240029693
# episode = 190 , reward =  38.8 mean losses: 0.12376086513201395
# train: ep: 193 update target_net !
# episode = 195 , reward =  30.4 mean losses: 0.15945553432764678
# episode = 200 , reward =  45.8 mean losses: 0.14577368646860123
#
# mean loss during training =  inf
# mean reward after training =  65.85 std: 26.994953232039503
# =================================================
#
# BUFFER_CAPACITY: 18000
# episode = 5 , reward =  9.4 mean losses: inf
# episode = 10 , reward =  65.8 mean losses: inf
# episode = 15 , reward =  9.6 mean losses: 0.0028898253144385914
# episode = 20 , reward =  10.6 mean losses: 0.0029135969340462575
# episode = 25 , reward =  9.6 mean losses: 0.0023917120524856728
# episode = 30 , reward =  9.4 mean losses: 0.0035597797985629817
# train: ep: 33 update target_net !
# episode = 35 , reward =  9.4 mean losses: 0.10339003626038046
# episode = 40 , reward =  9.0 mean losses: 0.047456479989565335
# episode = 45 , reward =  9.4 mean losses: 0.017283911368361226
# episode = 50 , reward =  10.2 mean losses: 0.009741801209747792
# episode = 55 , reward =  9.4 mean losses: 0.011127299908548594
# episode = 60 , reward =  9.6 mean losses: 0.009211403042586013
# episode = 65 , reward =  10.2 mean losses: 0.008831923796484868
# train: ep: 65 update target_net !
# episode = 70 , reward =  10.4 mean losses: 0.018170057372613388
# episode = 75 , reward =  15.4 mean losses: 0.014431233634240925
# episode = 80 , reward =  16.4 mean losses: 0.017044902666274345
# episode = 85 , reward =  10.8 mean losses: 0.013185791937368256
# episode = 90 , reward =  11.0 mean losses: 0.01277530356310308
# episode = 95 , reward =  12.6 mean losses: 0.013699419097974896
# train: ep: 97 update target_net !
# episode = 100 , reward =  20.2 mean losses: 0.030158491513016177
# episode = 105 , reward =  12.2 mean losses: 0.027226394787430764
# episode = 110 , reward =  19.0 mean losses: 0.021427548848665677
# episode = 115 , reward =  15.8 mean losses: 0.024682825803756712
# episode = 120 , reward =  17.2 mean losses: 0.023734645297129948
# episode = 125 , reward =  18.6 mean losses: 0.02830976617312239
# train: ep: 129 update target_net !
# episode = 130 , reward =  11.2 mean losses: 0.3198636695742607
# episode = 135 , reward =  45.0 mean losses: 0.03742454316595505
# episode = 140 , reward =  33.8 mean losses: 0.035338655687295474
# episode = 145 , reward =  39.2 mean losses: 0.055871858237645566
# episode = 150 , reward =  41.8 mean losses: 0.03732768073678017
# episode = 155 , reward =  13.2 mean losses: 0.33225158389125553
# episode = 160 , reward =  200.0 mean losses: 0.24436230771243572
#
# mean loss during training =  inf
# mean reward after training =  200.0 std: 0.0
# =================================================
#
# BUFFER_CAPACITY: 20000
# episode = 5 , reward =  17.8 mean losses: inf
# episode = 10 , reward =  18.2 mean losses: inf
# episode = 15 , reward =  9.6 mean losses: 0.008320127919432707
# episode = 20 , reward =  9.4 mean losses: 0.000297355831005714
# episode = 25 , reward =  15.6 mean losses: 0.00029573793514058565
# episode = 30 , reward =  9.2 mean losses: 0.00027206024969927967
# train: ep: 33 update target_net !
# episode = 35 , reward =  66.6 mean losses: 0.18386328717072806
# episode = 40 , reward =  9.2 mean losses: 0.014874533446011494
# episode = 45 , reward =  9.4 mean losses: 0.012588191874480495
# episode = 50 , reward =  41.2 mean losses: 0.009487986510906082
# episode = 55 , reward =  65.6 mean losses: 0.013584616376707952
# episode = 60 , reward =  9.8 mean losses: 0.010529688044794296
# episode = 65 , reward =  9.6 mean losses: 0.011211492617925008
# train: ep: 65 update target_net !
# episode = 70 , reward =  188.2 mean losses: 0.020597940402441336
# episode = 75 , reward =  137.2 mean losses: 0.015521659696888592
# episode = 80 , reward =  136.4 mean losses: 0.017817993791630633
# episode = 85 , reward =  30.4 mean losses: 0.01791344173410434
# episode = 90 , reward =  93.8 mean losses: 0.013509054077652896
# episode = 95 , reward =  15.0 mean losses: 0.015896796559294064
# train: ep: 97 update target_net !
# episode = 100 , reward =  9.6 mean losses: 0.04389023706316948
# episode = 105 , reward =  9.6 mean losses: 0.037008953474772475
# episode = 110 , reward =  47.0 mean losses: 0.03646010655211285
# episode = 115 , reward =  10.4 mean losses: 0.03495078117010139
# episode = 120 , reward =  24.2 mean losses: 0.0325777210528031
# episode = 125 , reward =  24.4 mean losses: 0.03383302316069603
# train: ep: 129 update target_net !
# episode = 130 , reward =  11.2 mean losses: 0.2641792952230102
# episode = 135 , reward =  9.6 mean losses: 0.07589479937757317
# episode = 140 , reward =  26.8 mean losses: 0.06051284528296927
# episode = 145 , reward =  10.0 mean losses: 0.07810868750754241
# episode = 150 , reward =  32.8 mean losses: 0.06579945915762116
# episode = 155 , reward =  9.8 mean losses: 0.06815928176045417
# episode = 160 , reward =  25.4 mean losses: 0.05756794066271848
# train: ep: 161 update target_net !
# episode = 165 , reward =  45.8 mean losses: 0.12070850928624471
# episode = 170 , reward =  58.0 mean losses: 0.07503462955355644
# episode = 175 , reward =  24.8 mean losses: 0.12132374942302704
# episode = 180 , reward =  36.0 mean losses: 0.08888518471609462
# episode = 185 , reward =  46.6 mean losses: 0.09176580645143986
# episode = 190 , reward =  46.4 mean losses: 0.12380589985034683
# train: ep: 193 update target_net !
# episode = 195 , reward =  72.6 mean losses: 0.1635995948953288
# episode = 200 , reward =  72.2 mean losses: 0.15821645865517278
#
# mean loss during training =  inf
# mean reward after training =  70.7 std: 2.8653097563788807
# =================================================
#
# BUFFER_CAPACITY: 30000
# episode = 5 , reward =  9.4 mean losses: inf
# episode = 10 , reward =  9.2 mean losses: inf
# episode = 15 , reward =  13.8 mean losses: 0.0012950686671371972
# episode = 20 , reward =  13.6 mean losses: 0.000696327099662826
# episode = 25 , reward =  15.8 mean losses: 0.0006382913138209419
# episode = 30 , reward =  10.2 mean losses: 0.0006889325617521535
# train: ep: 33 update target_net !
# episode = 35 , reward =  20.2 mean losses: 0.02947691200595153
# episode = 40 , reward =  16.8 mean losses: 0.01598713209386915
# episode = 45 , reward =  10.0 mean losses: 0.014638891690136754
# episode = 50 , reward =  11.0 mean losses: 0.013916284222865389
# episode = 55 , reward =  16.6 mean losses: 0.009870142812895425
# episode = 60 , reward =  15.6 mean losses: 0.010123836212894984
# episode = 65 , reward =  28.4 mean losses: 0.007756270790615907
# train: ep: 65 update target_net !
# episode = 70 , reward =  27.8 mean losses: 0.016595643168936174
# episode = 75 , reward =  70.6 mean losses: 0.015574895909854345
# episode = 80 , reward =  47.2 mean losses: 0.014853634361532472
# episode = 85 , reward =  31.6 mean losses: 0.012041460032221573
# episode = 90 , reward =  97.4 mean losses: 0.01243120110754309
# episode = 95 , reward =  47.0 mean losses: 0.01455934023808526
# train: ep: 97 update target_net !
# episode = 100 , reward =  10.4 mean losses: 0.02895031919082006
# episode = 105 , reward =  9.4 mean losses: 0.026201000045004644
# episode = 110 , reward =  10.6 mean losses: 0.028622756640498456
# episode = 115 , reward =  9.6 mean losses: 0.028284443432793897
# episode = 120 , reward =  70.4 mean losses: 0.021671915974687126
# episode = 125 , reward =  10.4 mean losses: 0.02443108106813123
# train: ep: 129 update target_net !
# episode = 130 , reward =  11.2 mean losses: 0.31275235265493395
# episode = 135 , reward =  9.2 mean losses: 0.055749849543314085
# episode = 140 , reward =  10.4 mean losses: 0.044183926863802805
# episode = 145 , reward =  11.4 mean losses: 0.04969581979371253
# episode = 150 , reward =  24.4 mean losses: 0.04381131837991151
# episode = 155 , reward =  18.2 mean losses: 0.055064375795747925
# episode = 160 , reward =  10.4 mean losses: 0.06416039346229463
# train: ep: 161 update target_net !
# episode = 165 , reward =  9.2 mean losses: 0.1046262588351965
# episode = 170 , reward =  36.6 mean losses: 0.1037299670279026
# episode = 175 , reward =  9.4 mean losses: 0.1371962990273129
# episode = 180 , reward =  43.2 mean losses: 0.10717970549555147
# episode = 185 , reward =  59.8 mean losses: 0.10030673518776893
# episode = 190 , reward =  57.8 mean losses: 0.11304640676826239
# train: ep: 193 update target_net !
# episode = 195 , reward =  85.4 mean losses: 0.18813911880607959
# episode = 200 , reward =  80.4 mean losses: 0.1815416697751392
#
# mean loss during training =  inf
# mean reward after training =  80.0 std: 3.5071355833500366
# =================================================
# <ipython-input-147-bf66a7cef7cc>:46: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()
# <ipython-input-147-bf66a7cef7cc>:49: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2.show()

# %%
df_res
# Out:
#                    1000        5000       10000       15000  18000      20000  \
# mean_reward   75.500000   49.550000   84.100000   65.850000  200.0   70.70000
# std_rewards    3.556684   18.744266   30.232268   26.994953    0.0    2.86531
# nb_episodes  200.000000  200.000000  200.000000  200.000000  159.0  200.00000
#
#                   30000
# mean_reward   80.000000
# std_rewards    3.507136
# nb_episodes  200.000000

# %% [markdown]
# ------------------------------------------
# - On remarque que la meilleur valeur est de 18000 où il a fallut 159 épisodes pour avoir un reward de 200.
# - On remarque que pour la valeur 1000 on obtient un mean_reward de 75 qui augmente progressivement, avec un petit écart type de 3.5
# - Pour la valeur de 5000 on observe un mean_reward de 49.5 mais avec une forte convergence.
# - Pour la valeur de 10000 on observe un mean_reward de 84.1 avec un gros std de 30 !
# - Pour la valeur 15000 on observe un mean_reward de 65.8 avec un gros std aussi, de ~27 !
# - Pour la valeur 20000 on observe un mean_reward de 70.7 avec un petit std de 2.8
# - Pour la valeur de 30000 on observe un mean_reward de 80 avec un léger std de 3.5
# ------------------------------------------
# - Le processus est stochastique. On observe d'autre valeurs à chaque run, mais les meilleurs valeurs observées sont entre [10000, 20000]
# ------------------------------------------
# - On remarque les courbes de loss augmentent par palier !
# ------------------------------------------
# - On peut déduire que plus le buffer_replay est large plus il y aura d'observations.
# - Plus il y'a d'observations (passées) plus le NN sera affecté par cette historique. On pourrait s'attendre à appercevoir un plus large std => de plus grande variance qui pourrait ne pas aboutir à une convergence assez vite.
# - Dans le casd inverse (petit BUFFER_CAPACITY) on remarquerait une plus petite varience vers la convergence.

# %% [markdown]
# #### Question 7
#
# Craft an experiment and study the influence of the `UPDATE_TARGET_EVERY` on the learning process (speed of *convergence*, training curves...)

# %%
fig1 = plt.figure(figsize=(20,20))
ax1 = plt.axes()

fig2 = plt.figure(figsize=(20,20))
ax2 = plt.axes()

df_res = pd.DataFrame(index=['mean_reward', 'std_reward', 'nb_episodes'])


BUFFER_CAPACITY = 16384
c_i = 0
for UPDATE_TARGET_EVERY in UPDATE_TARGET_EVERY_LIST:
    print("UPDATE_TARGET_EVERY:", UPDATE_TARGET_EVERY)
    # create instance of replay buffer
    replay_buffer = ReplayBuffer(BUFFER_CAPACITY)
    
    # create network and target network
    hidden_size = 128
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    q_net = Net(obs_size, hidden_size, n_actions)
    target_net = Net(obs_size, hidden_size, n_actions)
    
    # objective and optimizer
    objective = nn.MSELoss()
    optimizer = optim.Adam(params=q_net.parameters(), lr=LEARNING_RATE)
    
    # Run the training loop
    nb_ep, losses = train()

    # Evaluate the final policy
    rewards = eval_dqn(20)
    print("")
    print("mean loss during training = ", np.mean(losses))
    print("mean reward after training = ", np.mean(rewards), 'std:', np.std(rewards))
    print("=================================================")
    print()
    
    df_res[str(UPDATE_TARGET_EVERY)] = [np.mean(rewards), np.std(rewards), nb_ep]

    
    ax1.plot(rewards, label='rewards_update_target_every_' + str(UPDATE_TARGET_EVERY), c=colors[c_i])
    ax2.plot(losses, label='losses_update_target_every_' + str(UPDATE_TARGET_EVERY), c=colors[c_i], linestyle='-')
    c_i += 1
    

fig1.legend()    
fig1.show()

fig2.legend()    
fig2.show()
# Out:
# UPDATE_TARGET_EVERY: 10
# episode = 5 , reward =  9.6 mean losses: inf
# episode = 10 , reward =  9.4 mean losses: inf
# train: ep: 11 update target_net !
# episode = 15 , reward =  12.4 mean losses: 0.002206490928074345
# episode = 20 , reward =  9.4 mean losses: 0.0014426453271880746
# train: ep: 21 update target_net !
# episode = 25 , reward =  12.0 mean losses: 0.020185693095509823
# episode = 30 , reward =  25.4 mean losses: 0.010725583607221352
# train: ep: 31 update target_net !
# episode = 35 , reward =  47.8 mean losses: 0.06593923270702362
# episode = 40 , reward =  33.2 mean losses: 0.04026223352235375
# train: ep: 41 update target_net !
# episode = 45 , reward =  10.6 mean losses: 0.07895708722727639
# episode = 50 , reward =  28.8 mean losses: 0.05454797350252286
# train: ep: 51 update target_net !
# episode = 55 , reward =  49.4 mean losses: 0.09984003110892242
# episode = 60 , reward =  54.2 mean losses: 0.06892939284443855
# train: ep: 61 update target_net !
# episode = 65 , reward =  133.8 mean losses: 0.08241583820846346
# episode = 70 , reward =  24.0 mean losses: 0.0745964568729202
# train: ep: 71 update target_net !
# episode = 75 , reward =  110.2 mean losses: 0.11571075492783596
# episode = 80 , reward =  55.6 mean losses: 0.10741745890118182
# train: ep: 81 update target_net !
# episode = 85 , reward =  80.2 mean losses: 0.17299244517371767
# episode = 90 , reward =  200.0 mean losses: 0.16685321382605112
#
# mean loss during training =  inf
# mean reward after training =  200.0 std: 0.0
# =================================================
#
# UPDATE_TARGET_EVERY: 20
# episode = 5 , reward =  9.4 mean losses: inf
# episode = 10 , reward =  9.0 mean losses: inf
# episode = 15 , reward =  9.4 mean losses: 0.0014489664705858256
# episode = 20 , reward =  53.4 mean losses: 0.00019557518620179812
# train: ep: 21 update target_net !
# episode = 25 , reward =  62.2 mean losses: 0.0179470976030356
# episode = 30 , reward =  33.8 mean losses: 0.010714011616073549
# episode = 35 , reward =  97.0 mean losses: 0.008269999084214484
# episode = 40 , reward =  35.8 mean losses: 0.007221841556020081
# train: ep: 41 update target_net !
# episode = 45 , reward =  9.4 mean losses: 0.053030787374485626
# episode = 50 , reward =  44.0 mean losses: 0.02312519159168005
# episode = 55 , reward =  101.2 mean losses: 0.018087862939056423
# episode = 60 , reward =  14.2 mean losses: 0.016019165861131304
# train: ep: 61 update target_net !
# episode = 65 , reward =  10.0 mean losses: 0.05279412103647536
# episode = 70 , reward =  9.2 mean losses: 0.03512703958484861
# episode = 75 , reward =  11.6 mean losses: 0.03334324692304318
# episode = 80 , reward =  10.4 mean losses: 0.03320696085159268
# train: ep: 81 update target_net !
# episode = 85 , reward =  13.8 mean losses: 0.0811166912317276
# episode = 90 , reward =  27.4 mean losses: 0.05767975091224625
# episode = 95 , reward =  50.4 mean losses: 0.06014946076486792
# episode = 100 , reward =  66.8 mean losses: 0.07439574003219604
# train: ep: 101 update target_net !
# episode = 105 , reward =  64.2 mean losses: 0.10437999748521382
# episode = 110 , reward =  77.8 mean losses: 0.0976606814021414
# episode = 115 , reward =  70.8 mean losses: 0.11324434268933076
# episode = 120 , reward =  91.8 mean losses: 0.11563322469592094
# train: ep: 121 update target_net !
# episode = 125 , reward =  70.4 mean losses: 0.1647196862755752
# episode = 130 , reward =  86.0 mean losses: 0.15805886628536078
# episode = 135 , reward =  96.2 mean losses: 0.16494678378105163
# episode = 140 , reward =  80.4 mean losses: 0.14252091751944634
# train: ep: 141 update target_net !
# episode = 145 , reward =  89.2 mean losses: 0.21913780313399103
# episode = 150 , reward =  94.2 mean losses: 0.2681385626395543
# episode = 155 , reward =  79.4 mean losses: 0.20281351831826297
# episode = 160 , reward =  79.2 mean losses: 0.22767314658715174
# train: ep: 161 update target_net !
# episode = 165 , reward =  93.2 mean losses: 0.30573433885971707
# episode = 170 , reward =  62.2 mean losses: 0.290947450324893
# episode = 175 , reward =  78.4 mean losses: 0.33027614493455204
# episode = 180 , reward =  28.8 mean losses: 0.2919866727157073
# train: ep: 181 update target_net !
# episode = 185 , reward =  98.0 mean losses: 0.44977650472096037
# episode = 190 , reward =  61.0 mean losses: 0.4974787006011376
# episode = 195 , reward =  79.8 mean losses: 0.38932703305845673
# episode = 200 , reward =  62.6 mean losses: 0.3458622626282952
# train: ep: 201 update target_net !
#
# mean loss during training =  inf
# mean reward after training =  85.0 std: 30.32490725459849
# =================================================
#
# UPDATE_TARGET_EVERY: 30
# episode = 5 , reward =  8.8 mean losses: inf
# episode = 10 , reward =  9.4 mean losses: inf
# episode = 15 , reward =  9.4 mean losses: inf
# episode = 20 , reward =  17.0 mean losses: 0.005268599558621645
# episode = 25 , reward =  22.0 mean losses: 0.0010781337220508319
# episode = 30 , reward =  16.0 mean losses: 0.0010719189372406725
# train: ep: 31 update target_net !
# episode = 35 , reward =  9.0 mean losses: 0.030322365742176772
# episode = 40 , reward =  16.8 mean losses: 0.016341848234678137
# episode = 45 , reward =  9.6 mean losses: 0.016843155226004974
# episode = 50 , reward =  22.8 mean losses: 0.013613631815782614
# episode = 55 , reward =  20.2 mean losses: 0.015702001200142233
# episode = 60 , reward =  11.4 mean losses: 0.014804369377854624
# train: ep: 61 update target_net !
# episode = 65 , reward =  16.4 mean losses: 0.019937239633873106
# episode = 70 , reward =  59.0 mean losses: 0.014234051853418351
# episode = 75 , reward =  16.8 mean losses: 0.015953262875738897
# episode = 80 , reward =  58.2 mean losses: 0.019525078552154202
# episode = 85 , reward =  10.4 mean losses: 0.01632471985526775
# episode = 90 , reward =  20.4 mean losses: 0.02128541110349553
# train: ep: 91 update target_net !
# episode = 95 , reward =  101.0 mean losses: 0.039537261559494906
# episode = 100 , reward =  165.0 mean losses: 0.03209378640167415
# episode = 105 , reward =  200.0 mean losses: 0.04319401537297202
#
# mean loss during training =  inf
# mean reward after training =  200.0 std: 0.0
# =================================================
#
# UPDATE_TARGET_EVERY: 40
# episode = 5 , reward =  9.0 mean losses: inf
# episode = 10 , reward =  10.0 mean losses: inf
# episode = 15 , reward =  11.2 mean losses: 0.0012386712362058461
# episode = 20 , reward =  12.2 mean losses: 0.000761286998611121
# episode = 25 , reward =  16.2 mean losses: 0.0011837859942932568
# episode = 30 , reward =  9.4 mean losses: 0.0008929734205594287
# episode = 35 , reward =  14.6 mean losses: 0.000858243355261428
# episode = 40 , reward =  9.0 mean losses: 0.0008669971757626627
# train: ep: 41 update target_net !
# episode = 45 , reward =  9.4 mean losses: 0.026511549606527154
# episode = 50 , reward =  20.4 mean losses: 0.018634029205713887
# episode = 55 , reward =  10.4 mean losses: 0.013712171661226373
# episode = 60 , reward =  12.6 mean losses: 0.011477046258126697
# episode = 65 , reward =  9.4 mean losses: 0.0084308244820152
# episode = 70 , reward =  10.2 mean losses: 0.016845724630084904
# episode = 75 , reward =  9.2 mean losses: 0.01178682576317121
# episode = 80 , reward =  9.8 mean losses: 0.008589944336563349
# train: ep: 81 update target_net !
# episode = 85 , reward =  9.0 mean losses: 0.025152766592800618
# episode = 90 , reward =  9.6 mean losses: 0.020450653178462137
# episode = 95 , reward =  25.4 mean losses: 0.014392996827761332
# episode = 100 , reward =  34.8 mean losses: 0.016772518671738606
# episode = 105 , reward =  9.2 mean losses: 0.018814251676667483
# episode = 110 , reward =  17.4 mean losses: 0.02624505213820017
# episode = 115 , reward =  16.4 mean losses: 0.01602678912292634
# episode = 120 , reward =  10.8 mean losses: 0.016717317688744515
# train: ep: 121 update target_net !
# episode = 125 , reward =  9.8 mean losses: 0.03807165380567312
# episode = 130 , reward =  54.0 mean losses: 0.03712644661692056
# episode = 135 , reward =  9.8 mean losses: 0.04513447831074397
# episode = 140 , reward =  10.6 mean losses: 0.036815646663308145
# episode = 145 , reward =  10.0 mean losses: 0.04118832607160915
# episode = 150 , reward =  10.2 mean losses: 0.049473411636427045
# episode = 155 , reward =  9.8 mean losses: 0.047231818176805974
# episode = 160 , reward =  10.8 mean losses: 0.04771196022629738
# train: ep: 161 update target_net !
# episode = 165 , reward =  11.4 mean losses: 0.07492676344902618
# episode = 170 , reward =  10.4 mean losses: 0.06379879299889911
# episode = 175 , reward =  14.4 mean losses: 0.07807199367218548
# episode = 180 , reward =  30.2 mean losses: 0.06998852423081796
# episode = 185 , reward =  11.0 mean losses: 0.07419075216016462
# episode = 190 , reward =  11.8 mean losses: 0.08980364386330951
# episode = 195 , reward =  21.0 mean losses: 0.07319992674248559
# episode = 200 , reward =  9.8 mean losses: 0.07988307239221674
# train: ep: 201 update target_net !
#
# mean loss during training =  inf
# mean reward after training =  17.65 std: 16.45683748476602
# =================================================
#
# UPDATE_TARGET_EVERY: 50
# episode = 5 , reward =  12.2 mean losses: inf
# episode = 10 , reward =  12.2 mean losses: inf
# episode = 15 , reward =  27.2 mean losses: 0.27368512423709035
# episode = 20 , reward =  35.2 mean losses: 0.0013733975233902272
# episode = 25 , reward =  108.8 mean losses: 0.0008040207515781125
# episode = 30 , reward =  42.8 mean losses: 0.0006935400419428737
# episode = 35 , reward =  56.6 mean losses: 0.0005437146610347554
# episode = 40 , reward =  63.6 mean losses: 0.0006675017671974225
# episode = 45 , reward =  21.4 mean losses: 0.0005744584405975831
# episode = 50 , reward =  97.8 mean losses: 0.0005118599760746106
# train: ep: 51 update target_net !
# episode = 55 , reward =  9.2 mean losses: 0.03392349625937641
# episode = 60 , reward =  8.8 mean losses: 0.011329319545378287
# episode = 65 , reward =  9.0 mean losses: 0.015017413449558344
# episode = 70 , reward =  8.6 mean losses: 0.009856680090623822
# episode = 75 , reward =  9.4 mean losses: 0.013083537367896901
# episode = 80 , reward =  9.2 mean losses: 0.011359983545844443
# episode = 85 , reward =  9.4 mean losses: 0.01136356028728187
# episode = 90 , reward =  9.8 mean losses: 0.008256794977933168
# episode = 95 , reward =  16.2 mean losses: 0.010539226117543876
# episode = 100 , reward =  9.6 mean losses: 0.008939127326898631
# train: ep: 101 update target_net !
# episode = 105 , reward =  9.8 mean losses: 0.020759174259515796
# episode = 110 , reward =  10.4 mean losses: 0.02077056560665369
# episode = 115 , reward =  9.6 mean losses: 0.021395399020268366
# episode = 120 , reward =  106.8 mean losses: 0.018424641057921975
# episode = 125 , reward =  10.0 mean losses: 0.01995988447840015
# episode = 130 , reward =  9.6 mean losses: 0.019057441941078973
# episode = 135 , reward =  10.0 mean losses: 0.015877313557125274
# episode = 140 , reward =  10.0 mean losses: 0.015741118874687415
# episode = 145 , reward =  9.8 mean losses: 0.018437713488108583
# episode = 150 , reward =  10.0 mean losses: 0.01713105878077967
# train: ep: 151 update target_net !
# episode = 155 , reward =  58.8 mean losses: 0.03258643430941131
# episode = 160 , reward =  10.6 mean losses: 0.03361334931105375
# episode = 165 , reward =  21.0 mean losses: 0.02876470424234867
# episode = 170 , reward =  9.4 mean losses: 0.032953735779632225
# episode = 175 , reward =  78.0 mean losses: 0.03225881367607016
# episode = 180 , reward =  74.6 mean losses: 0.04269529953598976
# episode = 185 , reward =  34.6 mean losses: 0.036116960979998114
# episode = 190 , reward =  75.8 mean losses: 0.037778429248753714
# episode = 195 , reward =  71.8 mean losses: 0.035971678653731944
# episode = 200 , reward =  9.6 mean losses: 0.03489970566616172
# train: ep: 201 update target_net !
#
# mean loss during training =  inf
# mean reward after training =  14.55 std: 11.460693696282089
# =================================================
#
# UPDATE_TARGET_EVERY: 100
# episode = 5 , reward =  97.8 mean losses: inf
# episode = 10 , reward =  43.0 mean losses: inf
# episode = 15 , reward =  9.0 mean losses: 0.00040732773292499286
# episode = 20 , reward =  9.2 mean losses: 0.0004028497013922145
# episode = 25 , reward =  9.4 mean losses: 0.00038115918207701975
# episode = 30 , reward =  9.6 mean losses: 0.0003874128306051716
# episode = 35 , reward =  9.2 mean losses: 0.00047111614460873443
# episode = 40 , reward =  9.4 mean losses: 0.00030039243483770406
# episode = 45 , reward =  10.0 mean losses: 0.0005870401297355643
# episode = 50 , reward =  9.2 mean losses: 0.0003892595575760222
# episode = 55 , reward =  42.0 mean losses: 0.0007404084767172621
# episode = 60 , reward =  9.8 mean losses: 0.0007297925463221459
# episode = 65 , reward =  9.6 mean losses: 0.0007097920006344793
# episode = 70 , reward =  9.8 mean losses: 0.00034437470539059077
# episode = 75 , reward =  9.8 mean losses: 0.0007872491218482278
# episode = 80 , reward =  9.6 mean losses: 0.0012436488302358026
# episode = 85 , reward =  9.4 mean losses: 0.0006667238400229413
# episode = 90 , reward =  9.6 mean losses: 0.0003883188661088103
# episode = 95 , reward =  9.6 mean losses: 0.0005365607082947261
# episode = 100 , reward =  9.4 mean losses: 0.000679591263178736
# train: ep: 101 update target_net !
# episode = 105 , reward =  9.2 mean losses: 0.03161508838335673
# episode = 110 , reward =  9.6 mean losses: 0.023714905546512455
# episode = 115 , reward =  9.2 mean losses: 0.01813577777264934
# episode = 120 , reward =  9.4 mean losses: 0.02146245968262
# episode = 125 , reward =  9.4 mean losses: 0.016564999914003745
# episode = 130 , reward =  9.8 mean losses: 0.01940262835705653
# episode = 135 , reward =  9.2 mean losses: 0.014208109118044376
# episode = 140 , reward =  8.8 mean losses: 0.013894784497097135
# episode = 145 , reward =  9.2 mean losses: 0.012056654104246544
# episode = 150 , reward =  9.6 mean losses: 0.013535115324581662
# episode = 155 , reward =  9.8 mean losses: 0.013460920192301273
# episode = 160 , reward =  9.2 mean losses: 0.01097056616951401
# episode = 165 , reward =  9.6 mean losses: 0.011827786834063854
# episode = 170 , reward =  8.8 mean losses: 0.012604925176128745
# episode = 175 , reward =  9.2 mean losses: 0.009882282573156632
# episode = 180 , reward =  9.2 mean losses: 0.011419007001677528
# episode = 185 , reward =  9.4 mean losses: 0.010873818346722559
# episode = 190 , reward =  9.4 mean losses: 0.012700530467554927
# episode = 195 , reward =  9.4 mean losses: 0.012850934872403741
# episode = 200 , reward =  9.6 mean losses: 0.010480027558514848
# train: ep: 201 update target_net !
#
# mean loss during training =  inf
# mean reward after training =  9.45 std: 0.5894913061275798
# =================================================
#
# UPDATE_TARGET_EVERY: 1000
# episode = 5 , reward =  9.4 mean losses: inf
# episode = 10 , reward =  9.6 mean losses: inf
# episode = 15 , reward =  9.2 mean losses: 0.017491727211588138
# episode = 20 , reward =  9.4 mean losses: 0.0027157526023478974
# episode = 25 , reward =  9.2 mean losses: 0.002387130185245321
# episode = 30 , reward =  9.2 mean losses: 0.002397931180894375
# episode = 35 , reward =  10.0 mean losses: 0.002508062607375905
# episode = 40 , reward =  9.8 mean losses: 0.0015565284217397373
# episode = 45 , reward =  9.6 mean losses: 0.002185952183531804
# episode = 50 , reward =  9.4 mean losses: 0.0023066141875460744
# episode = 55 , reward =  9.0 mean losses: 0.0034503566178803644
# episode = 60 , reward =  9.4 mean losses: 0.0012909283713352952
# episode = 65 , reward =  9.6 mean losses: 0.0017006239557469432
# episode = 70 , reward =  9.2 mean losses: 0.0014594099096332986
# episode = 75 , reward =  9.4 mean losses: 0.0017463122367980363
# episode = 80 , reward =  9.2 mean losses: 0.001557426558892158
# episode = 85 , reward =  9.8 mean losses: 0.0016030053926729842
# episode = 90 , reward =  9.4 mean losses: 0.002069372933224908
# episode = 95 , reward =  9.0 mean losses: 0.002059781273904567
# episode = 100 , reward =  9.4 mean losses: 0.00203788564335007
# episode = 105 , reward =  9.8 mean losses: 0.0017229897202923894
# episode = 110 , reward =  9.6 mean losses: 0.0025141220627119764
# episode = 115 , reward =  9.6 mean losses: 0.0027900226931605074
# episode = 120 , reward =  9.4 mean losses: 0.0031429153168573976
# episode = 125 , reward =  9.8 mean losses: 0.0032013634530206523
# episode = 130 , reward =  9.4 mean losses: 0.002065575473049345
# episode = 135 , reward =  9.6 mean losses: 0.0015530359285714274
# episode = 140 , reward =  9.6 mean losses: 0.0036851006637637815
# episode = 145 , reward =  9.6 mean losses: 0.0030755322077311575
# episode = 150 , reward =  9.2 mean losses: 0.002029687811789865
# episode = 155 , reward =  9.2 mean losses: 0.0022835222880530637
# episode = 160 , reward =  9.2 mean losses: 0.002653976022783253
# episode = 165 , reward =  8.4 mean losses: 0.002734665950161538
# episode = 170 , reward =  9.4 mean losses: 0.00196657320484519
# episode = 175 , reward =  9.0 mean losses: 0.0026941317006606946
# episode = 180 , reward =  8.4 mean losses: 0.002002956229262054
# episode = 185 , reward =  9.4 mean losses: 0.001993306661461247
# episode = 190 , reward =  8.8 mean losses: 0.0031487085104275206
# episode = 195 , reward =  9.2 mean losses: 0.0021067375912227565
# episode = 200 , reward =  9.0 mean losses: 0.005041156997322105
#
# mean loss during training =  inf
# mean reward after training =  9.4 std: 0.7348469228349535
# =================================================
# <ipython-input-150-c51774f45845>:49: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig1.show()
# <ipython-input-150-c51774f45845>:52: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2.show()

# %%
print("mean rewards:")
df_res
# Out:
# mean rewards:
#                 10          20     30          40          50         100  \
# mean_reward  200.0   85.000000  200.0   17.650000   14.550000    9.450000
# std_reward     0.0   30.324907    0.0   16.456837   11.460694    0.589491
# nb_episodes   89.0  200.000000  104.0  200.000000  200.000000  200.000000
#
#                    1000
# mean_reward    9.400000
# std_reward     0.734847
# nb_episodes  200.000000

# %% [markdown]
# ------------------------------------------
# - On remarque que pour des petites valeurs de UPDATE_TARGET_EVERY on converge vite.
# - On remarque que plus la valeur de UPDATE_TARGET_EVERY est grande plus nos reward diminuent !
# -> Plus on met à jour rapidement notre target network plus nous obtenons de meilleur rewards !
# ------------------------------------------
# - On remarque les courbes de loss augmentent par palier !
# ------------------------------------------
# - On peut déduire que le UPDATE_TARGET_EVERY doit etre assez petit pour que la MAJ se fasse au plus vite.
# - Au plus on augmente cette valeur au plus notre NN n'apprendra pas (assez souvent) !

# %% [markdown]
# #### Question 8
#
# If you have the computer power to do so, try to do a grid search on those two hyper-parameters and comment the results. Otherwise, study the influence of another hyper-parameter.

# %% [markdown]
# ## Discretization

# %% [markdown]
# It is natural to use a function approximator like a neural network to approximate the $Q$ function in a continuous environment. Another natural but unscalable way to do handle continuous state-action space is **discretization**.

# %% [markdown]
# Discretize the environment of your choice (cartpole or mountain car) and run one of the algorithms that you know to compute an approximation of the optimal $Q$ function.

# %% [markdown]
# Once you are satisfied with your results, you may plot the *optimal phase diagram* of the system. For instance, you may get something like this for the mountain car environment.
# ![Phase diagram](./phase_plot.png)

# %%
# Import and initialize Mountain Car Environment
env = gym.make('MountainCar-v0')
env.reset()

# Define Q-learning function
def QLearning(env, learning, discount, epsilon, min_eps, episodes):
    # Determine size of discretized state space
    num_states = (env.observation_space.high - env.observation_space.low)*np.array([10, 100])
    num_states = np.round(num_states, 0).astype(int) + 1
    #print('num_states:', num_states.shape, num_states)
    
    # Initialize Q table
    Q = np.random.uniform(low = -1, high = 1, 
                          size = (num_states[0], num_states[1], 
                                  env.action_space.n))
    #print("Q:", Q.shape)
    
    # Initialize variables to track rewards
    reward_list = []
    ave_reward_list = []
    
    # Calculate episodic reduction in epsilon
    reduction = (epsilon - min_eps)/episodes
    
    # Run Q learning algorithm
    for i in range(episodes):
        # Initialize parameters
        done = False
        tot_reward, reward = 0,0
        state = env.reset()
        
        # Discretize state
        state_adj = (state - env.observation_space.low)*np.array([10, 100])
        state_adj = np.round(state_adj, 0).astype(int)
        # print("state_adj:", state_adj.shape, state_adj)
    
        while done != True:   
            # Render environment for last five episodes
            #if i >= (episodes - 20):
            #    env.render()
                
            # Determine next action - epsilon greedy strategy
            if np.random.random() < 1 - epsilon:
                action = np.argmax(Q[state_adj[0], state_adj[1]]) 
            else:
                action = np.random.randint(0, env.action_space.n)
                
            # Get next state and reward
            state2, reward, done, info = env.step(action) 
            
            # Discretize state2
            state2_adj = (state2 - env.observation_space.low)*np.array([10, 100])
            state2_adj = np.round(state2_adj, 0).astype(int)
            #print("state2_adj:", state2_adj.shape, state2_adj)
            
            
            #Allow for terminal states
            if done and state2[0] >= 0.5:
                Q[state_adj[0], state_adj[1], action] = reward
                
            # Adjust Q value for current state
            else:
                delta = learning*(reward + 
                                 discount*np.max(Q[state2_adj[0], 
                                                   state2_adj[1]]) - 
                                 Q[state_adj[0], state_adj[1],action])
                Q[state_adj[0], state_adj[1],action] += delta
                                     
            # Update variables
            tot_reward += reward
            state_adj = state2_adj
        
        # Decay epsilon
        if epsilon > min_eps:
            epsilon -= reduction
        
        # Track rewards
        reward_list.append(tot_reward)
        
        if (i+1) % 100 == 0:
            ave_reward = np.mean(reward_list)
            ave_reward_list.append(ave_reward)
            reward_list = []
            
        if (i+1) % 100 == 0:    
            print('Episode {} Average Reward: {}'.format(i+1, ave_reward))
            
    env.close()
    
    return ave_reward_list, Q

# %%
# Run Q-learning algorithm
rewards, q = QLearning(env, 0.2, 0.9, 0.8, 0, 5000)
# Out:
# Episode 100 Average Reward: -200.0
# Episode 200 Average Reward: -200.0
# Episode 300 Average Reward: -200.0
# Episode 400 Average Reward: -200.0
# Episode 500 Average Reward: -200.0
# Episode 600 Average Reward: -200.0
# Episode 700 Average Reward: -200.0
# Episode 800 Average Reward: -200.0
# Episode 900 Average Reward: -200.0
# Episode 1000 Average Reward: -200.0
# Episode 1100 Average Reward: -200.0
# Episode 1200 Average Reward: -200.0
# Episode 1300 Average Reward: -200.0
# Episode 1400 Average Reward: -200.0
# Episode 1500 Average Reward: -200.0
# Episode 1600 Average Reward: -200.0
# Episode 1700 Average Reward: -200.0
# Episode 1800 Average Reward: -200.0
# Episode 1900 Average Reward: -200.0
# Episode 2000 Average Reward: -200.0
# Episode 2100 Average Reward: -200.0
# Episode 2200 Average Reward: -200.0
# Episode 2300 Average Reward: -200.0
# Episode 2400 Average Reward: -200.0
# Episode 2500 Average Reward: -200.0
# Episode 2600 Average Reward: -199.98
# Episode 2700 Average Reward: -200.0
# Episode 2800 Average Reward: -200.0
# Episode 2900 Average Reward: -200.0
# Episode 3000 Average Reward: -199.08
# Episode 3100 Average Reward: -200.0
# Episode 3200 Average Reward: -200.0
# Episode 3300 Average Reward: -200.0
# Episode 3400 Average Reward: -198.79
# Episode 3500 Average Reward: -200.0
# Episode 3600 Average Reward: -199.97
# Episode 3700 Average Reward: -198.36
# Episode 3800 Average Reward: -196.61
# Episode 3900 Average Reward: -197.44
# Episode 4000 Average Reward: -199.89
# Episode 4100 Average Reward: -197.96
# Episode 4200 Average Reward: -194.86
# Episode 4300 Average Reward: -196.88
# Episode 4400 Average Reward: -198.1
# Episode 4500 Average Reward: -195.81
# Episode 4600 Average Reward: -196.36
# Episode 4700 Average Reward: -195.52
# Episode 4800 Average Reward: -185.23
# Episode 4900 Average Reward: -168.05
# Episode 5000 Average Reward: -156.69

# %%
# Plot Rewards
plt.plot(100*(np.arange(len(rewards)) + 1), rewards)
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Average Reward vs Episodes')
plt.savefig('rewards.png')
plt.show()
plt.close()

# %%
plt.clf()
c = plt.imshow(q.T[0], origin='lower')
plt.colorbar(c)
plt.show()

# %%
xs = []
ys = []
vs = []

for i,x in enumerate(q):
    for j,y in enumerate(x):
        state_cont = np.divide(np.array([i,j]),np.array([10, 100])) + env.observation_space.low
        xs += [state_cont[0]]
        ys += [state_cont[1]]
        vs += [np.max(x[j])]
        
plt.scatter(ys,xs,c=vs)

# %% [markdown]
# ## Bonus: SAIL-DQN
#
#
# In this section, we will add the SAIL bonus to DQN.
#
# SAIL (from [*Self-Imitation Advantage Learning*](https://arxiv.org/abs/2012.11989) [Ferret et al., 2020]) modifies DQN to add a self-imitation bonus. Self-imitation consists in reproducing actions that performed better than expected, *i.e.* better than the current value estimate. It is especially useful in tasks with sparse rewards, where at first it is uncommon to get positive rewards due to the initially random exploration of the agent. With self-imitation, the agent has incentive to reproduce actions that led to these uncommon rewards.
#
# An important quantity for SAIL is the **return** $G_t$, or the cumulative sum of rewards to-go. It corresponds to the *observed* discounted sum of rewards starting from state $s_t$:
#
# $$G_t = \sum_{t'=t}^T \gamma^{t' - t} r(s_{t'}, a_{t'}).$$
#
# Since we need that quantity to compute the SAIL bonus, we will need to observe full episodes before saving them to the replay buffer.
#
# Then, SAIL modifies the Q-learning update as follows:
#
# $$
# y_{i, SAIL} = r_{i, SAIL} + \gamma \max_{a'} Q(s_i', a', \theta^-),
# $$
# where
# $$
# r_{i, SAIL} = r_i + \alpha \Big(\max\{G_i, Q(s_i, a_i, \theta^-)\} - \max_{a'} Q(s_i, a', \theta^-)\Big).
# $$
#
# Let us break down this modification, which can be seen as adding a bonus to the reward.
#
# The term $\max\{G_i, Q(s_i, a_i, \theta^-)\}$ is the maximum of two return estimates: $G_i$ is the Monte Carlo return estimate (*i.e.* obtained via simulation) and $Q(s_i, a_i, \theta^-)$ is the agent's return estimate (*i.e.* estimated from previous experience). Hence, this first term is an optimistic estimate of the return.
#
# The term $\max_{a'} Q(s_i, a', \theta^-)$ is a value estimate. Instead of using the observed action (*i.e.* the one actually taken by the agent), it uses the most probable action (which is the argmax).
#
# Subtracting these two terms give an optimistic version of the advantage $A_i = G_i - \max_{a'} Q(s_i, a', \theta^-)$. The advantage roughly measures how much we gain by taking an action that differs from the one we usually take. Using it as a bonus encourages actions that lead to better results than currently expected.
#
# SAIL modifies DQN as follows:
#
# 1.   Transitions should now store the observed return $G_i$ as well. $G_i$ is unknown until the end of the episode is reached. So, at each time $t$, the agent has observed the transitions $(s_i, a_i, r_i, s_i')_{i=1}^{t-1}$, which are stored in a **temporary replay buffer**.
#
# 2.   Take actions as in DQN and observe rewards and next states.
#
# 3.   When the end of the episode is reached, returns $(G_i)_{i=0}^T$ are calculated. Returns are added to the transitions. All transitions are added to the **replay buffer**, which now stores returns as well.
#
# 4.  Sample a minibatch $\mathcal{B}$ containing $B$ transitions from the replay buffer. Using this minibatch, we define the loss:
#
# $$
# L(\theta) = \sum_{(s_i, a_i, r_i, s_i') \in \mathcal{B}}
# \left[
# Q(s_i, a_i, \theta) -  y_{i, SAIL}
# \right]^2
# $$
#
# 5. Do the rest as in DQN.
#
#
#
#
#
# `choose_action`, `get_q` and `eval_dqn` remain the same.
#
# To be implemented:
# * `update_sail`, compared to `update`, modifies $y_i$ as explained above.
# * `train_sail` adds several steps to `train`.
#
# Tip #1: `replay_buffer` now contains returns as well.
#
# Tip #2: in the computed advantage, use $Q(s_i, a_i, \theta^-)$, not $Q(s_i, a_i)$. It makes the bonus more stable.
#
# Tip #3: `torch.maximum` can be used to compute the element-wise max between two arrays.

# %% [markdown]
# #### Question 9
#
# Implement `update_sail` function.

# %%
 def update_sail(state, action, reward, next_state, done):
    """
    ** TO BE COMPLETED **
    """
    
    # add data to temporary replay buffer
    if done:
        next_state = None
    replay_buffer_temp.push(state, action, reward, next_state)
    
    if len(replay_buffer) < BATCH_SIZE:
        return np.inf
    
    # get batch
    transitions = replay_buffer.sample(BATCH_SIZE)

    # Compute loss - TO BE IMPLEMENTED!
    values  = torch.zeros(BATCH_SIZE)   # to be computed using batch
    targets = torch.zeros(BATCH_SIZE)   # to be computed using batch
    loss = objective(values, targets)
     
    # Optimize the model - UNCOMMENT!
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
    
    return loss.detach().numpy()

# %% [markdown]
# #### Question 10
#
# Implement the training loop.

# %%
def get_episode_returns(rewards):
    returns_reversed = accumulate(rewards[::-1],
                                lambda x, y: x*GAMMA + y)
    return list(returns_reversed)[::-1]

def train_sail():
    state = env.reset()
    epsilon = EPSILON_START
    ep = 0
    total_time = 0
    while ep < N_EPISODES:
        action = choose_action(state, epsilon)

        # take action and update replay buffer and networks
        next_state, reward, done, _ = env.step(action)
        loss = update_sail(state, action, reward, next_state, done)

        # update state
        state = next_state

        # end episode if done
        if done:
            state = env.reset()
            ep   += 1
            if ( (ep+1)% EVAL_EVERY == 0):
                rewards = eval_dqn()
                print("episode =", ep+1, ", reward = ", np.mean(rewards))
                if np.mean(rewards) >= REWARD_THRESHOLD:
                    break

            # fetch transitions from the temporary memory
            transitions = replay_buffer_temp.memory

            # calculate episode returns
            # TO IMPLEMENT

            # transfer transitions completed with returns to main memory
            # TO IMPLEMENT

            # reset the temporary memory
            # TO IMPLEMENT

            # update target network
            if ep % UPDATE_TARGET_EVERY == 0:
                target_net.load_state_dict(q_net.state_dict())
            # decrease epsilon
            epsilon = EPSILON_MIN + (EPSILON_START - EPSILON_MIN) * \
                            np.exp(-1. * ep / DECREASE_EPSILON )    

        total_time += 1

# Run the training loop
train_sail()

# Evaluate the final policy
rewards = eval_dqn(20)
print("")
print("mean reward after training = ", np.mean(rewards))

# %% [markdown]
# #### Question 11
#
# Display your policy in action.

# %%
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay
from IPython.display import clear_output
from pathlib import Path
import base64

def show_video():
    html = []
    for mp4 in Path("videos").glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append('''<video alt="{}" autoplay 
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>'''.format(mp4, video_b64.decode('ascii')))
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))
    
env = Monitor(env, './videos', force=True, video_callable=lambda episode: True)

for episode in range(1):
    done = False
    state = env.reset()
    while not done:
        action = choose_action(state, 0.0)
        state, reward, done, info = env.step(action)
env.close()
# show_video()
