# %% [markdown]
# ## Author
# - Selim Lakhdar
#     - selim.lakhdar@gmail.com
#     - selim.lakhdar.etu@univ-lille.fr
# ------------------------------

# %% [markdown]
# ## Import Libraries

# %%
from bs4 import BeautifulSoup,SoupStrainer

import os
import time
import re
import pandas as pd
import numpy as np

import spacy
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

# %%
random_state = 42

# %% [markdown]
# ## Reuters: Topic Prediction

# %% [markdown]
# ### Load Data

# %%
def data_loader():
    l_topics, l_title, l_body = [], [], []

    for i in range(22):
        # 17 file contains error
        if i == 17:
            continue

        file_name = f'../data/reuteurs21578/reut2-{i:03d}.sgm'
        print(file_name)
        f = open(file_name, 'r')
        data = f.read()

        soup = BeautifulSoup(data, "html.parser")
        contents = soup.findAll('reuters')

        topic_err, title_err, body_err = 0, 0, 0

        for content in contents:
            # topics
            try:
                topics = content.findAll("topics")[0].findAll("d")
                tmp_topics = []
                for topic in topics:
                    tmp_topics += [topic.text]

                if len(tmp_topics) == 0:
                    topic_err += 1
                    l_topics += [['Unkown']]
                else:
                    l_topics += [tmp_topics]
            except:
                topic_err += 1
                l_topics += ['Unkown']
            # title
            try:
                title = content.findAll("title")[0].text
                l_title += [title]
            except:
                title_err += 1
                l_title += ['Unkown']
            # body
            try:        
                body = content.findAll("body")[0].text
                l_body += [body]
            except:
                body_err += 1
                l_body += ['Unkown']

        print(i, "l_topics:", len(l_topics), "topic_err:", topic_err)
        print(i, "l_title:", len(l_title), "title_err:", title_err)
        print(i, "l_body:", len(l_body), "body_err:", body_err)
        print("===================================")

    reuteurs_df = pd.DataFrame()
    reuteurs_df['topics'] = l_topics
    reuteurs_df['title'] = l_title
    reuteurs_df['body'] = l_body
    return reuteurs_df

# %%
reuteurs_df = data_loader()
reuteurs_df
# Out:
# ../data/reuteurs21578/reut2-000.sgm
# 0 l_topics: 1000 topic_err: 488
# 0 l_title: 1000 title_err: 15
# 0 l_body: 1000 body_err: 75
# ===================================
# ../data/reuteurs21578/reut2-001.sgm
# 1 l_topics: 2000 topic_err: 476
# 1 l_title: 2000 title_err: 5
# 1 l_body: 2000 body_err: 70
# ===================================
# ../data/reuteurs21578/reut2-002.sgm
# 2 l_topics: 3000 topic_err: 436
# 2 l_title: 3000 title_err: 3
# 2 l_body: 3000 body_err: 94
# ===================================
# ../data/reuteurs21578/reut2-003.sgm
# 3 l_topics: 4000 topic_err: 409
# 3 l_title: 4000 title_err: 1
# 3 l_body: 4000 body_err: 74
# ===================================
# ../data/reuteurs21578/reut2-004.sgm
# 4 l_topics: 5000 topic_err: 431
# 4 l_title: 5000 title_err: 5
# 4 l_body: 5000 body_err: 103
# ===================================
# ../data/reuteurs21578/reut2-005.sgm
# 5 l_topics: 6000 topic_err: 387
# 5 l_title: 6000 title_err: 3
# 5 l_body: 6000 body_err: 76
# ===================================
# ../data/reuteurs21578/reut2-006.sgm
# 6 l_topics: 7000 topic_err: 382
# 6 l_title: 7000 title_err: 2
# 6 l_body: 7000 body_err: 79
# ===================================
# ../data/reuteurs21578/reut2-007.sgm
# 7 l_topics: 8000 topic_err: 412
# 7 l_title: 8000 title_err: 8
# 7 l_body: 8000 body_err: 110
# ===================================
# ../data/reuteurs21578/reut2-008.sgm
# 8 l_topics: 9000 topic_err: 428
# 8 l_title: 9000 title_err: 5
# 8 l_body: 9000 body_err: 83
# ===================================
# ../data/reuteurs21578/reut2-009.sgm
# 9 l_topics: 10000 topic_err: 416
# 9 l_title: 10000 title_err: 4
# 9 l_body: 10000 body_err: 96
# ===================================
# ../data/reuteurs21578/reut2-010.sgm
# 10 l_topics: 11000 topic_err: 434
# 10 l_title: 11000 title_err: 5
# 10 l_body: 11000 body_err: 89
# ===================================
# ../data/reuteurs21578/reut2-011.sgm
# 11 l_topics: 12000 topic_err: 398
# 11 l_title: 12000 title_err: 5
# 11 l_body: 12000 body_err: 88
# ===================================
# ../data/reuteurs21578/reut2-012.sgm
# 12 l_topics: 13000 topic_err: 392
# 12 l_title: 13000 title_err: 9
# 12 l_body: 13000 body_err: 70
# ===================================
# ../data/reuteurs21578/reut2-013.sgm
# 13 l_topics: 14000 topic_err: 746
# 13 l_title: 14000 title_err: 335
# 13 l_body: 14000 body_err: 363
# ===================================
# ../data/reuteurs21578/reut2-014.sgm
# 14 l_topics: 15000 topic_err: 769
# 14 l_title: 15000 title_err: 302
# 14 l_body: 15000 body_err: 344
# ===================================
# ../data/reuteurs21578/reut2-015.sgm
# 15 l_topics: 16000 topic_err: 432
# 15 l_title: 16000 title_err: 3
# 15 l_body: 16000 body_err: 76
# ===================================
# ../data/reuteurs21578/reut2-016.sgm
# 16 l_topics: 17000 topic_err: 407
# 16 l_title: 17000 title_err: 6
# 16 l_body: 17000 body_err: 53
# ===================================
# ../data/reuteurs21578/reut2-018.sgm
# 18 l_topics: 18000 topic_err: 565
# 18 l_title: 18000 title_err: 3
# 18 l_body: 18000 body_err: 93
# ===================================
# ../data/reuteurs21578/reut2-019.sgm
# 19 l_topics: 19000 topic_err: 613
# 19 l_title: 19000 title_err: 8
# 19 l_body: 19000 body_err: 98
# ===================================
# ../data/reuteurs21578/reut2-020.sgm
# 20 l_topics: 20000 topic_err: 531
# 20 l_title: 20000 title_err: 3
# 20 l_body: 20000 body_err: 223
# ===================================
# ../data/reuteurs21578/reut2-021.sgm
# 21 l_topics: 20578 topic_err: 249
# 21 l_title: 20578 title_err: 3
# 21 l_body: 20578 body_err: 118
# ===================================
#                                            topics  \
# 0                                         [cocoa]
# 1                                        [Unkown]
# 2                                        [Unkown]
# 3                                        [Unkown]
# 4      [grain, wheat, corn, barley, oat, sorghum]
# ...                                           ...
# 20573                                      [ship]
# 20574                                       [ipi]
# 20575                                      [gold]
# 20576                                    [Unkown]
# 20577                                    [Unkown]
#
#                                                    title  \
# 0                                     BAHIA COCOA REVIEW
# 1              STANDARD OIL <SRD> TO FORM FINANCIAL UNIT
# 2             TEXAS COMMERCE BANCSHARES <TCB> FILES PLAN
# 3           TALKING POINT/BANKAMERICA <BAC> EQUITY OFFER
# 4       NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE
# ...                                                  ...
# 20573  JAPAN/INDIA CONFERENCE CUTS GULF WAR RISK CHARGES
# 20574      SOVIET INDUSTRIAL GROWTH/TRADE SLOWER IN 1987
# 20575     SIX KILLED IN SOUTH AFRICAN GOLD MINE ACCIDENT
# 20576   PROJECTIONS SHOW SWISS VOTERS WANT TRIED PARTIES
# 20577   AMERICAN EXCHANGE INTRODUCES INSTITUTIONAL INDEX
#
#                                                     body
# 0      Showers continued throughout the week in\nthe ...
# 1      Standard Oil Co and BP North America\nInc said...
# 2      Texas Commerce Bancshares Inc's Texas\nCommerc...
# 3      BankAmerica Corp is not under\npressure to act...
# 4      The U.S. Agriculture Department\nreported the ...
# ...                                                  ...
# 20573  The Japan/India-Pakistan-Gulf/Japan\nshipping ...
# 20574  The Soviet Union's industrial output is\ngrowi...
# 20575  Six black miners have been killed\nand two inj...
# 20576  The prospect of a dominant alliance of\nsocial...
# 20577  The American Stock Exchange said it has\nintro...
#
# [20578 rows x 3 columns]

# %% [markdown]
# ### Topic Counter: Extract TOP 6

# %%
topic_counter = {}
for topics in reuteurs_df['topics']:
    for t in topics:
        if t in topic_counter.keys():
            topic_counter[t] += 1
        else:
            topic_counter[t] = 1

pd.DataFrame.from_dict(topic_counter, orient='index', columns=['freq']).sort_values(['freq'], ascending=False)[:10]
# Out:
#           freq
# Unkown    9801
# earn      3939
# acq       2293
# money-fx   726
# grain      593
# crude      579
# trade      503
# interest   479
# wheat      288
# ship       286

# %%
best_topics = ['earn', 'acq', 'money-fx', 'grain', 'crude', 'trade']

# %%
l = []
for index, row in reuteurs_df.iterrows():
    if len(row['topics']) == 1:
        for t in row['topics']:
            if t in best_topics:
                # from array to elem
                row[0] = row[0][0]
                l += [row]
                
top_topics_reuteurs_df = pd.DataFrame(l)
top_topics_reuteurs_df
# Out:
#          topics                                              title  \
# 8          earn        CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT
# 9           acq    COMPUTER TERMINAL SYSTEMS <CPML> COMPLETES SALE
# 10         earn                        COBANCO INC <CBCO> YEAR NET
# 12         earn           AM INTERNATIONAL INC <AM> 2ND QTR JAN 31
# 13         earn                 BROWN-FORMAN INC <BFD> 4TH QTR NET
# ...         ...                                                ...
# 20554       acq  CABLE AND WIRELESS TO MERGE TWO H.K. UNITS INT...
# 20555  money-fx  BALLADUR INSISTS ON MAINTENANCE OF LOUVRE ACCORDS
# 20561     trade      PHILIPPINE TRADE GAP WIDENS IN JANUARY-AUGUST
# 20567     crude  IRAN, SOVIET UNION TO SWAP CRUDE, REFINED PROD...
# 20570       acq      N.Z.'S CHASE CORP MAKES OFFER FOR ENTREGROWTH
#
#                                                     body
# 8      Champion Products Inc said its\nboard of direc...
# 9      Computer Terminal Systems Inc said\nit has com...
# 10     Shr 34 cts vs 1.19 dlrs\n    Net 807,000 vs 2,...
# 12     Oper shr loss two cts vs profit seven cts\n   ...
# 13     Shr one dlr vs 73 cts\n    Net 12.6 mln vs 15....
# ...                                                  ...
# 20554                                             Unkown
# 20555  French Finance Minister Edouard Balladur\nissu...
# 20561  The Philippines' trade deficit widened to\n542...
# 20567  The Soviet Union has agreed to supply\nIran wi...
# 20570  Chase Corp Ltd <CHCA.WE> said it will\nmake an...
#
# [7169 rows x 3 columns]

# %% [markdown]
# ### Preprocessor: Text Cleaning

# %%
def preprocess_text_clean(msg):
    msg = msg.replace('\n', ' ')
    msg = msg.replace('\r', ' ')
    msg = msg.replace('Reuter\x03', ' ')
    msg = msg.replace('REUTER\x03', ' ')
    msg = msg.replace('Reuter \x03', ' ')
    
    # remove <tag>
    #msg = re.sub(r'<(?<=<).*?(?=>)>', ' ', msg)
    msg = msg.replace('<', ' ')
    msg = msg.replace('>', ' ')
    
    # remove  -
    msg = msg.replace(' - ', ' ')
    
    # reformat  ,
    msg = msg.replace(' , ', ', ')
    
    # join tokens
    msg = ' '.join(msg.split())
    
    return msg

# %% [markdown]
# ### Tokenzier: Spacy

# %%
nlp = spacy.load('en_core_web_lg')

def lemma_tokenizer(sentence):
    doc = nlp(sentence)
    tokens = [token.lemma_ for token in doc if token.lemma_ not in stopwords.words('english')]
    return tokens

# %% [markdown]
# ### Bag of Words (CountVectorizer)

# %%
vectorizer = CountVectorizer(lowercase=True, 
                             preprocessor=preprocess_text_clean, 
                             tokenizer=lemma_tokenizer, 
                             ngram_range=(1,3),
                            max_features=50000)

# %% [markdown]
# ### Split

# %%
X = top_topics_reuteurs_df['body']
y = top_topics_reuteurs_df['topics'].astype("category").cat.codes

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

# %%
start = time.time()
X_train = vectorizer.fit_transform(X_train)
end = time.time()
print('elapsed time:', end - start)
# Out:
# elapsed time: 123.78480052947998

# %%
print("Shape: ",X_train.shape)
vectorizer.vocabulary_
# Out:
# Shape:  (5018, 50000)
# {'TransCanada': 21771,
#  'PipeLines': 19915,
#  'Ltd': 18215,
#  'deny': 28560,
#  'report': 41300,
#  'raise': 40523,
#  'offer': 37532,
#  'Dome': 15159,
#  'Petroleum': 19822,
#  'DMP': 14820,
#  '5.5': 9992,
#  'billion': 25381,
#  'canadian': 25952,
#  'dlrs': 29089,
#  '4.3': 9505,
#  '.': 3304,
#  'Canadian': 13726,
#  'Broadcasting': 13274,
#  'Corp': 14622,
#  '(': 921,
#  'CBC': 13452,
#  ')': 1000,
#  'late': 33761,
#  'last': 33642,
#  'night': 37297,
#  'say': 42767,
#  "'s": 558,
#  'new': 37173,
#  'bid': 25264,
#  'reject': 41065,
#  ',': 1041,
#  'accept': 22898,
#  '5.1': 9965,
#  'dlr': 29007,
#  'Amoco': 12063,
#  '"': 1,
#  'still': 46296,
#  'want': 49187,
#  'acquire': 23056,
#  'asset': 24683,
#  'prepared': 39234,
#  'negotiate': 37047,
#  'however': 32397,
#  'present': 39240,
#  'proposal': 39993,
#  'company': 26942,
#  'since': 45554,
#  'April': 12155,
#  '16': 6436,
#  'refuse': 40991,
#  'date': 28268,
#  'president': 39250,
#  'Gerald': 16398,
#  'consist': 27447,
#  'two': 47670,
#  'part': 38308,
#  '--': 3295,
#  '4.5': 9524,
#  'cash': 26104,
#  'security': 44014,
#  'one': 37811,
#  'payment': 38490,
#  'creditor': 27836,
#  'base': 25025,
#  'future': 31707,
#  'profit': 39620,
#  'week': 49246,
#  'value': 47979,
#  'first': 31166,
#  'spokesman': 46035,
#  'today': 47314,
#  'increase': 32767,
#  'estimate': 30398,
#  'recent': 40788,
#  'gain': 31725,
#  'stock': 46311,
#  'halt': 32153,
#  'Toronto': 21725,
#  'Stock': 21365,
#  'Exchange': 15633,
#  'pende': 38729,
#  'clarification': 26604,
#  'trade': 47425,
#  '1.70': 5544,
#  'per': 38751,
#  'share': 44282,
#  'ago': 23440,
#  '1.10': 5234,
#  'TransCanada PipeLines': 21776,
#  'PipeLines Ltd': 19916,
#  'deny report': 28561,
#  'raise offer': 40559,
#  'offer Dome': 37559,
#  'Dome Petroleum': 15172,
#  'Petroleum Ltd': 19845,
#  'Ltd DMP': 18231,
#  '5.5 billion': 9993,
#  'billion canadian': 25436,
#  'canadian dlrs': 25964,
#  '4.3 billion': 9506,
#  'billion .': 25393,
#  '. report': 4772,
#  'Canadian Broadcasting': 13735,
#  'Broadcasting Corp': 13277,
#  'Corp (': 14625,
#  'CBC )': 13453,
#  'late last': 33770,
#  'last night': 33713,
#  'say TransCanada': 43028,
#  "TransCanada 's": 21772,
#  "'s new": 768,
#  'new bid': 37182,
#  'Dome ,': 15168,
#  ', accept': 1811,
#  '5.1 billion': 9966,
#  'billion dlr': 25444,
#  'dlr bid': 29021,
#  'Amoco Corp': 12064,
#  '. "': 3306,
#  '" still': 489,
#  'want acquire': 49189,
#  "Dome 's": 15160,
#  "'s asset": 621,
#  'negotiate .': 37048,
#  '. however': 4512,
#  'however ,': 32398,
#  ', present': 2494,
#  'new proposal': 37224,
#  'proposal company': 40021,
#  'company since': 27168,
#  'April 16': 12193,
#  'date ,': 28269,
#  ', "': 1042,
#  '" say': 445,
#  '. TransCanada': 4105,
#  'say proposal': 43556,
#  '4.5 billion': 9525,
#  'billion dlrs': 25453,
#  'dlrs cash': 29298,
#  'cash security': 26187,
#  'one billion': 37839,
#  'payment creditor': 38495,
#  'base future': 25037,
#  'future profit': 31719,
#  'profit .': 39626,
#  '. last': 4560,
#  'last week': 33741,
#  'week ,': 49250,
#  ', TransCanada': 1754,
#  'dlrs ,': 29094,
#  ', spokesman': 2719,
#  'today say': 47337,
#  'say company': 43142,
#  'estimate value': 30415,
#  "'s stock": 871,
#  'stock .': 46316,
#  '. Dome': 3655,
#  'Toronto Stock': 21729,
#  'Stock Exchange': 21366,
#  "'s offer": 771,
#  'offer .': 37539,
#  'last trade': 33737,
#  '1.70 dlrs': 5546,
#  'dlrs per': 29409,
#  'per share': 38778,
#  'share .': 44333,
#  '. two': 4983,
#  'two week': 47756,
#  'week ago': 49259,
#  'ago ,': 23441,
#  'offer ,': 37534,
#  ', Dome': 1437,
#  '1.10 dlrs': 5236,
#  'TransCanada PipeLines Ltd': 21777,
#  'offer Dome Petroleum': 37560,
#  'Dome Petroleum Ltd': 15174,
#  'Petroleum Ltd DMP': 19846,
#  'billion canadian dlrs': 25437,
#  'Canadian Broadcasting Corp': 13736,
#  'Broadcasting Corp (': 13278,
#  "say TransCanada 's": 43029,
#  'billion dlr bid': 25446,
#  '. " still': 3423,
#  "Dome 's asset": 15162,
#  '. however ,': 4513,
#  'date , "': 28270,
#  ', " say': 1078,
#  '4.5 billion dlrs': 9526,
#  'dlrs cash security': 29304,
#  'one billion dlrs': 37841,
#  '. last week': 4562,
#  'last week ,': 33743,
#  '4.3 billion dlrs': 9507,
#  'billion dlrs ,': 25454,
#  "'s stock .": 873,
#  'Toronto Stock Exchange': 21730,
#  "TransCanada 's offer": 21774,
#  "'s offer .": 773,
#  'dlrs per share': 29412,
#  'per share .': 38780,
#  'two week ago': 47758,
#  'week ago ,': 49260,
#  "'s offer ,": 772,
#  'oper': 37968,
#  'shr': 44816,
#  '41': 9615,
#  'ct': 27895,
#  'vs': 48102,
#  'loss': 34234,
#  '1.13': 5249,
#  'Oper': 19435,
#  'net': 37069,
#  '3,093,000': 8652,
#  'revs': 42084,
#  '35.9': 9276,
#  'mln': 35802,
#  '31.1': 9080,
#  'avg': 24830,
#  'shrs': 45299,
#  'note': 37409,
#  ':': 11618,
#  'current': 28141,
#  'year': 49661,
#  'exclude': 30512,
#  '2.5': 7376,
#  '33': 9157,
#  '/': 5037,
#  'benefit': 25224,
#  'tax': 46885,
#  'carryforward': 26077,
#  'include': 32528,
#  'pretax': 39275,
#  '1.2': 5281,
#  'sale': 42636,
#  'export': 30750,
#  'quota': 40456,
#  'right': 42449,
#  '-': 2881,
#  'charge': 26501,
#  'five': 31251,
#  'discontinue': 28779,
#  'operation': 38030,
#  '1985': 6808,
#  'eight': 30012,
#  'mth': 36844,
#  'end': 30153,
#  'Dec': 14908,
#  '31': 9034,
#  'change': 26455,
#  'calendar': 25922,
#  'previous': 39294,
#  'fiscal': 31220,
#  '27': 8268,
#  'oper shr': 37977,
#  'shr profit': 45243,
#  'profit 41': 39713,
#  '41 ct': 9616,
#  'ct vs': 27990,
#  'vs loss': 49041,
#  '1.13 dlrs': 5251,
#  'dlrs Oper': 29261,
#  'Oper net': 19437,
#  'net profit': 37138,
#  '3,093,000 vs': 8653,
#  'revs 35.9': 42323,
#  '35.9 mln': 9277,
#  'mln vs': 36246,
#  'vs 31.1': 48672,
#  '31.1 mln': 9081,
#  'mln avg': 35931,
#  'avg shrs': 24831,
#  'note :': 37412,
#  ': current': 11670,
#  'current year': 28187,
#  'year exclude': 49822,
#  'exclude gain': 30523,
#  '2.5 mln': 7380,
#  'mln dlrs': 35994,
#  'dlrs 33': 29226,
#  '33 ct': 9159,
#  'ct /': 27901,
#  '/ shr': 5058,
#  'benefit tax': 25248,
#  'tax loss': 46913,
#  'loss carryforward': 34534,
#  'include pretax': 32662,
#  'pretax gain': 39278,
#  'gain 1.2': 31731,
#  '1.2 mln': 5287,
#  'dlrs sale': 29447,
#  'export quota': 30783,
#  'right .': 42458,
#  '. year': 5007,
#  'year -': 49700,
#  '- ago': 3031,
#  'include charge': 32580,
#  'charge five': 26510,
#  'five mln': 31275,
#  'dlrs discontinue': 29322,
#  'discontinue operation': 28780,
#  'operation .': 38034,
#  '. 1985': 3450,
#  'mth end': 36869,
#  'end Dec': 30171,
#  'Dec 31': 14910,
#  '31 ,': 9035,
#  ', 1985': 1144,
#  '1985 .': 6816,
#  'year ,': 49673,
#  ', company': 1984,
#  'company change': 27021,
#  'calendar year': 25925,
#  'fiscal year': 31241,
#  'year end': 49804,
#  'end April': 30167,
#  'April 27': 12247,
#  '27 ,': 8269,
#  'oper shr profit': 37980,
#  '41 ct vs': 9620,
#  'ct vs loss': 28081,
#  'dlrs Oper net': 29262,
#  'Oper net profit': 19440,
#  'revs 35.9 mln': 42324,
#  '35.9 mln vs': 9278,
#  'mln vs 31.1': 36409,
#  'vs 31.1 mln': 48673,
#  'mln avg shrs': 35932,
#  'note : current': 37427,
#  ': current year': 11674,
#  'year exclude gain': 49824,
#  '2.5 mln dlrs': 7383,
#  'ct / shr': 27902,
#  'benefit tax loss': 25249,
#  'tax loss carryforward': 46914,
#  'include pretax gain': 32664,
#  'gain 1.2 mln': 31732,
#  '1.2 mln dlrs': 5288,
#  'mln dlrs sale': 36083,
#  '. year -': 5010,
#  'year - ago': 49702,
#  'include charge five': 32581,
#  'charge five mln': 26511,
#  'five mln dlrs': 31278,
#  'mln dlrs discontinue': 36030,
#  'dlrs discontinue operation': 29323,
#  'discontinue operation .': 28782,
#  'operation . 1985': 38036,
#  'end Dec 31': 30172,
#  'Dec 31 ,': 14911,
#  '31 , 1985': 9036,
#  ', 1985 .': 1147,
#  '. year ,': 5009,
#  'year , company': 49678,
#  ', company change': 1989,
#  'fiscal year end': 31247,
#  'year end April': 49808,
#  'April 27 ,': 12248,
#  '27 , 1985': 8270,
#  'japanese': 33462,
#  'government': 31930,
#  'appear': 24478,
#  'little': 34152,
#  'settle': 44228,
#  'dispute': 28826,
#  'U.S.': 21851,
#  'computer': 27308,
#  'chip': 26540,
#  'analyst': 24111,
#  'official': 37652,
#  'threaten': 47213,
#  'impose': 32486,
#  'tariff': 46863,
#  'worth': 49472,
#  '300': 9022,
#  'electronic': 30075,
#  'retaliation': 41910,
#  'Japan': 17643,
#  'allege': 23779,
#  'failure': 30867,
#  'keep': 33546,
#  'pact': 38268,
#  'microchip': 35670,
#  'sign': 45474,
#  'September': 20883,
#  'Foreign': 15959,
#  'Ministry': 18831,
#  'tell': 46978,
#  'Reuters': 20439,
#  'must': 36913,
#  'persuade': 38881,
#  'United': 22193,
#  'States': 21315,
#  'wait': 49178,
#  'step': 46246,
#  'take': 46740,
#  'effect': 29961,
#  'agreement': 23564,
#  'sell': 44072,
#  'cost': 27659,
#  'non': 37362,
#  'u.s.': 47763,
#  'Markets': 18503,
#  'open': 37940,
#  'far': 30923,
#  'Chip': 14087,
#  'due': 29687,
#  '17': 6529,
#  'International': 17461,
#  'Trade': 21739,
#  'Industry': 17390,
#  'MITI': 18323,
#  'already': 23851,
#  'order': 38127,
#  'chipmaker': 26552,
#  'cut': 28211,
#  'production': 39585,
#  'dry': 29684,
#  'source': 45747,
#  'cheap': 26517,
#  'third': 47184,
#  'country': 27740,
#  'regulated': 41027,
#  'price': 39331,
#  'I': 17130,
#  'sure': 46656,
#  'much': 36891,
#  'Jardine': 17704,
#  'Fleming': 15936,
#  'Securities': 20830,
#  'Nick': 19206,
#  'Edwards': 15459,
#  'plan': 38935,
#  'call': 25926,
#  'beyond': 25256,
#  'seek': 44047,
#  'although': 24037,
#  'would': 49480,
#  'continue': 27509,
#  'press': 39265,
#  'user': 47956,
#  'buy': 25844,
#  'foreign': 31408,
#  'good': 31909,
#  'firm': 31139,
#  'consider': 27418,
#  'Matsushita': 18541,
#  'Electric': 15476,
#  'Industrial': 17365,
#  'Co': 14222,
#  'rapid': 40612,
#  'import': 32456,
#  'likely': 34097,
#  'Most': 18942,
#  'exporter': 30788,
#  'hard': 32175,
#  'hit': 32294,
#  'implement': 32451,
#  'levy': 34056,
#  'consumer': 27476,
#  'product': 39557,
#  'rather': 40692,
#  'remain': 41184,
#  'place': 38923,
#  'length': 34000,
#  'time': 47283,
#  'complete': 27250,
#  'erosion': 30379,
#  'Tom': 21719,
#  'Murtha': 18981,
#  'James': 17595,
#  'Capel': 13772,
#  'Co.': 14343,
#  'electronics': 30095,
#  'industry': 32963,
#  'powerful': 39161,
#  'stop': 46426,
#  'recovery': 40889,
#  'delay': 28531,
#  'another': 24367,
#  'also': 23882,
#  'harm': 32181,
#  'offshore': 37700,
#  'reduce': 40905,
#  'demand': 28543,
#  'semiconductor': 44125,
#  'try': 47638,
#  'american': 24054,
#  'approach': 24520,
#  'full': 31643,
#  'expand': 30585,
#  'thing': 47168,
#  'maker': 34954,
#  'final': 31058,
#  'hurt': 32413,
#  'market': 35197,
#  'reflect': 40961,
#  'see': 44039,
#  'strategic': 46443,
#  'frustration': 31633,
#  'vast': 48016,
#  'surplus': 46660,
#  'argue': 24600,
#  'solve': 45709,
#  'problem': 39510,
#  'may': 35410,
#  'action': 23197,
#  'pledge': 39020,
#  'Carole': 13866,
#  'Ryavec': 20593,
#  'Salomon': 20671,
#  'Brothers': 13301,
#  'Asia': 12427,
#  'major': 34784,
#  'overall': 38229,
#  'issue': 33426,
#  'stimulate': 46306,
#  'domestic': 29604,
#  'economy': 29936,
#  'move': 36832,
#  'away': 24847,
#  'dependent': 28580,
#  'REUTER': 20234,
#  '\x03': 0,
#  'japanese government': 33484,
#  'government appear': 31937,
#  'new offer': 37210,
#  'settle dispute': 44230,
#  'dispute U.S.': 28829,
#  'U.S. computer': 21951,
#  'computer chip': 27312,
#  'chip ,': 26541,
#  ', trade': 2800,
#  'trade analyst': 47444,
#  'government official': 31945,
#  'official say': 37679,
#  'say .': 42781,
#  '. U.S.': 4115,
#  'impose tariff': 32493,
#  '300 mln': 9023,
#  'dlrs japanese': 29369,
#  'japanese electronic': 33479,
#  'electronic export': 30076,
#  'export U.S.': 30760,
#  'U.S. ,': 21855,
#  ', retaliation': 2606,
#  'retaliation Japan': 41913,
#  "Japan 's": 17644,
#  "'s allege": 608,
#  'allege failure': 23784,
#  'pact microchip': 38275,
#  'microchip trade': 35674,
#  'sign last': 45492,
#  'last September': 33680,
#  'September .': 20885,
#  '. Foreign': 3706,
#  'Foreign Ministry': 15962,
#  'Ministry official': 18836,
#  'official tell': 37688,
#  'tell Reuters': 46984,
#  '" Japan': 114,
#  'Japan ,': 17657,
#  ', must': 2386,
#  'United States': 22206,
#  'step take': 46249,
#  'take effect': 46769,
#  'effect .': 29964,
#  '" U.S.': 157,
#  'allege ,': 23780,
#  'agreement ,': 23565,
#  ', Japan': 1542,
#  'non -': 37363,
#  '- u.s.': 3267,
#  'open Japan': 37944,
#  'far U.S.': 30928,
#  'U.S. Chip': 21869,
#  'sale .': 42640,
#  'U.S. tariff': 22015,
#  'due take': 29711,
#  'effect April': 29965,
#  'April 17': 12196,
#  '17 .': 6534,
#  '. analyst': 4220,
#  'analyst note': 24173,
#  'note Japan': 37460,
#  "'s Ministry": 586,
#  'Ministry International': 18834,
#  'International Trade': 17496,
#  'Trade Industry': 21745,
#  'Industry (': 17391,
#  '( MITI': 965,
#  'MITI )': 18325,
#  'cut production': 28230,
#  'third country': 47187,
#  '- regulated': 3203,
#  'price .': 39338,
#  '" I': 103,
#  'I sure': 17149,
#  'much ,': 36892,
#  'say Jardine': 42976,
#  'Jardine Fleming': 17705,
#  ') Ltd': 1012,
#  'Ltd analyst': 18244,
#  'analyst Nick': 24135,
#  'Nick Edwards': 19207,
#  'Edwards .': 15460,
#  '. MITI': 3866,
#  'MITI official': 18327,
#  'plan call': 38951,
#  'production cut': 39599,
#  'seek ,': 44048,
#  ', although': 1864,
#  'would continue': 49508,
#  'chip user': 26549,
#  'foreign good': 31436,
#  'good .': 31912,
#  '. spokesman': 4900,
#  'electronic firm': 30077,
#  'firm say': 31154,
#  'say would': 43862,
#  'would consider': 49507,
#  'consider buy': 27423,
#  'buy U.S.': 25862,
#  'Matsushita Electric': 18542,
#  'Electric Industrial': 15481,
#  'Industrial Co': 17366,
#  'spokesman say': 46049,
#  'increase import': 32805,
#  '. Most': 3906,
#  'Most analyst': 18943,
#  'analyst say': 24178,
#  'say japanese': 43362,
#  'hard hit': 32178,
#  'tariff ,': 46864,
#  ', would': 2870,
#  'consumer electronic': 27478,
#  'electronic product': 30088,
#  'microchip .': 35672,
#  'remain place': 41229,
#  'length time': 34001,
#  'time ,': 47284,
#  ', complete': 2003,
#  'export United': 30761,
#  'States ,': 21317,
#  'say Tom': 43026,
#  'Tom Murtha': 21720,
#  ', analyst': 1870,
#  'analyst James': 24131,
#  'James Capel': 17600,
#  'Capel Co.': 13778,
#  'Co. "': 14344,
#  '" japanese': 321,
#  'electronics industry': 30097,
#  'another year': 24408,
#  'say tariff': 43792,
#  'tariff would': 46882,
#  'would also': 49492,
#  'harm U.S.': 32182,
#  'U.S. Industry': 21900,
#  'semiconductor U.S.': 44129,
#  'U.S. firm': 21971,
#  'try sell': 47646,
#  'sell .': 44075,
#  '" american': 191,
#  'Edwards say': 15461,
#  '" want': 513,
#  'want expand': 49191,
#  '( U.S.': 981,
#  'U.S. )': 21854,
#  ') export': 1021,
#  'export ,': 30751,
#  ', last': 2312,
#  'market ,': 35201,
#  'say dispute': 43199,
#  'industry ,': 32967,
#  ', also': 1859,
#  'trade surplus': 47517,
#  'surplus .': 46662,
#  'analyst argue': 24158,
#  'problem Japan': 39516,
#  'may take': 35474,
#  'take action': 46756,
#  'semiconductor pact': 44138,
#  'pact .': 38272,
#  'Carole Ryavec': 13867,
#  'analyst Salomon': 24144,
#  'Salomon Brothers': 20672,
#  'Brothers Asia': 13304,
#  'Asia Ltd': 12429,
#  'Ltd ,': 18219,
#  ', say': 2618,
#  'say "': 42768,
#  '" major': 348,
#  'stimulate domestic': 46307,
#  'domestic economy': 29612,
#  'export -': 30754,
#  'economy .': 29939,
#  '" REUTER': 143,
#  'REUTER \x03': 20235,
#  ', trade analyst': 2801,
#  'government official say': 31946,
#  'official say .': 37681,
#  'say . U.S.': 42821,
#  '300 mln dlrs': 9025,
#  'mln dlrs japanese': 36049,
#  'dlrs japanese electronic': 29370,
#  "retaliation Japan 's": 41914,
#  "Japan 's allege": 17646,
#  "'s allege failure": 609,
#  'pact microchip trade': 38276,
#  'sign last September': 45493,
#  'last September .': 33682,
#  '. Foreign Ministry': 3707,
#  'Foreign Ministry official': 15963,
#  'Ministry official tell': 18838,
#  'official tell Reuters': 37689,
#  'take effect .': 46770,
#  '. " U.S.': 3330,
#  'non - u.s.': 37382,
#  'take effect April': 46771,
#  'effect April 17': 29966,
#  'April 17 .': 12198,
#  '. analyst note': 4224,
#  "note Japan 's": 37461,
#  "Japan 's Ministry": 17645,
#  "'s Ministry International": 587,
#  'Ministry International Trade': 18835,
#  'International Trade Industry': 17497,
#  'Trade Industry (': 21746,
#  'Industry ( MITI': 17392,
#  '( MITI )': 966,
#  'non - regulated': 37380,
#  'price . "': 39339,
#  '. " I': 3316,
#  '" I sure': 111,
#  'much , "': 36893,
#  '" say Jardine': 453,
#  'analyst Nick Edwards': 24136,
#  'MITI official say': 18328,
#  'firm say would': 31156,
#  'say would consider': 43866,
#  'Matsushita Electric Industrial': 18543,
#  'Electric Industrial Co': 15482,
#  '. Most analyst': 3907,
#  'Most analyst say': 18944,
#  'tariff , would': 46865,
#  'microchip . "': 35673,
#  'remain place length': 41230,
#  'export United States': 30762,
#  'United States ,': 22208,
#  'States , "': 21318,
#  '" say Tom': 456,
#  'say Tom Murtha': 43027,
#  'analyst James Capel': 24132,
#  'James Capel Co.': 17602,
#  'Capel Co. "': 13779,
#  'year , "': 49674,
#  '" say .': 448,
#  'say . analyst': 42831,
#  '. analyst say': 4226,
#  'say tariff would': 43793,
#  'sell . "': 44076,
#  'Edwards say .': 15462,
#  'say . "': 42783,
#  '. " want': 3432,
#  '( U.S. )': 982,
#  'market , "': 35202,
#  'trade surplus .': 47519,
#  'semiconductor pact .': 44139,
#  'analyst Salomon Brothers': 24145,
#  'Salomon Brothers Asia': 20673,
#  'Brothers Asia Ltd': 13305,
#  'Ltd , say': 18226,
#  ', say "': 2619,
#  'economy . "': 29940,
#  '. " REUTER': 3325,
#  '" REUTER \x03': 144,
#  'group': 32027,
#  'Chicago': 14061,
#  'Insurance': 17419,
#  'Fla.': 15927,
#  'real': 40726,
#  'estate': 30392,
#  'stake': 46117,
#  'Tandy': 21569,
#  'Brands': 13182,
#  'Inc': 17234,
#  '6.9': 10615,
#  'pct': 38506,
#  'total': 47371,
#  'filing': 31045,
#  'Commission': 14451,
#  'common': 26902,
#  'May': 18551,
#  '21': 7752,
#  'June': 17791,
#  '9': 11419,
#  'addition': 23244,
#  '5.2': 9976,
#  'hold': 32300,
#  'previously': 39307,
#  'group company': 32046,
#  'company include': 27061,
#  'Chicago -': 14064,
#  '- base': 3048,
#  'Insurance Co': 17420,
#  'Corp ,': 14627,
#  '. ,': 3440,
#  ', Fla.': 1469,
#  'Fla. ,': 15928,
#  ', real': 2554,
#  'real estate': 40727,
#  'firm ,': 31141,
#  'say raise': 43586,
#  'raise stake': 40573,
#  'Brands Inc': 13183,
#  'share ,': 44284,
#  ', 6.9': 1261,
#  '6.9 pct': 10618,
#  'pct total': 38697,
#  'total .': 47373,
#  '. filing': 4452,
#  'filing Securities': 31049,
#  'Securities Exchange': 20837,
#  'Exchange Commission': 15636,
#  'Commission ,': 14456,
#  ', group': 2236,
#  'group say': 32077,
#  'say buy': 43117,
#  'common share': 26908,
#  'share May': 44408,
#  'May 21': 18582,
#  'June 9': 17822,
#  'dlrs addition': 29271,
#  ', 5.2': 1236,
#  '5.2 pct': 9979,
#  'pct ,': 38509,
#  ', hold': 2257,
#  'previously .': 39311,
#  'Chicago - base': 14065,
#  ', Fla. ,': 1470,
#  ', real estate': 2555,
#  'firm , say': 31142,
#  ', say raise': 2652,
#  'say raise stake': 43593,
#  ', 6.9 pct': 1262,
#  '6.9 pct total': 10619,
#  'pct total .': 38699,
#  'total . filing': 47374,
#  '. filing Securities': 4453,
#  'filing Securities Exchange': 31050,
#  'Securities Exchange Commission': 20838,
#  'Exchange Commission ,': 15638,
#  'Commission , group': 14458,
#  ', group say': 2241,
#  'group say buy': 32079,
#  'share , 5.2': 44292,
#  ', 5.2 pct': 1237,
#  'saudi': 42757,
#  'arabian': 24579,
#  'Oil': 19390,
#  'Minister': 18793,
#  'Hisham': 16949,
#  'Nazer': 19101,
#  'reiterate': 41056,
#  'kingdom': 33565,
#  'commitment': 26880,
#  'December': 14919,
#  'OPEC': 19317,
#  'accord': 22928,
#  'boost': 25656,
#  'world': 49433,
#  'oil': 37704,
#  'stabilize': 46102,
#  'Saudi': 20738,
#  'Press': 20060,
#  'Agency': 11875,
#  'ask': 24661,
#  'agency': 23404,
#  'fall': 30881,
#  'free': 31591,
#  'Arabia': 12325,
#  'fully': 31673,
#  'adhere': 23266,
#  '...': 5020,
#  'never': 37169,
#  'pronounced': 39960,
#  'circumstance': 26574,
#  'main': 34746,
#  'architect': 24590,
#  'agree': 23490,
#  'output': 38185,
#  'ceiling': 26247,
#  '7.25': 10983,
#  'return': 41933,
#  'fix': 31299,
#  'around': 24605,
#  '18': 6613,
#  'dollar': 29573,
#  'barrel': 24995,
#  'saudi arabian': 42758,
#  'arabian Oil': 24580,
#  'Oil Minister': 19403,
#  'Minister Hisham': 18807,
#  'Hisham Nazer': 16950,
#  'reiterate kingdom': 41058,
#  "kingdom 's": 33566,
#  'last December': 33653,
#  "December 's": 14920,
#  "'s OPEC": 589,
#  'OPEC accord': 19324,
#  'boost world': 25665,
#  'world oil': 49455,
#  'oil price': 37768,
#  ', official': 2423,
#  '. ask': 4238,
#  'market oil': 35279,
#  'price ,': 39333,
#  ', Nazer': 1615,
#  'Nazer say': 19103,
#  'say Saudi': 43011,
#  'Saudi Arabia': 20739,
#  'sell oil': 44103,
#  'circumstance .': 26576,
#  '" Saudi': 147,
#  'main architect': 34747,
#  'December pact': 14941,
#  'OPEC agree': 19325,
#  'agree cut': 23525,
#  'oil output': 37761,
#  'output ceiling': 38189,
#  'ceiling 7.25': 26253,
#  '7.25 pct': 10984,
#  'pct return': 38669,
#  'return fix': 41942,
#  'fix price': 31307,
#  'price around': 39353,
#  'around 18': 24612,
#  'dollar barrel': 29585,
#  'barrel .': 24999,
#  'saudi arabian Oil': 42759,
#  'arabian Oil Minister': 24581,
#  'Oil Minister Hisham': 19405,
#  'Minister Hisham Nazer': 18808,
#  "reiterate kingdom 's": 41059,
#  "last December 's": 33654,
#  "December 's OPEC": 14921,
#  'boost world oil': 25666,
#  'world oil price': 49457,
#  'market , official': 35210,
#  'say . ask': 42833,
#  'oil price ,': 37769,
#  ', Nazer say': 1616,
#  'Nazer say Saudi': 19106,
#  'say Saudi Arabia': 43012,
#  '. " Saudi': 3327,
#  '" Saudi Arabia': 148,
#  'ceiling 7.25 pct': 26254,
#  'return fix price': 41943,
#  'fix price around': 31308,
#  'price around 18': 39354,
#  'nine': 37317,
#  'three': 47216,
#  'dilute': 28703,
#  '15': 6307,
#  'extraordinary': 30824,
#  'income': 32727,
#  'seven': 44235,
#  'four': 31513,
#  'offset': 37694,
#  'writedown': 49646,
#  'gas': 31778,
#  'property': 39968,
#  'Oper shr': 19441,
#  'shr nine': 45233,
#  'nine ct': 37322,
#  'vs three': 49166,
#  'three ct': 47232,
#  'ct Oper': 27919,
#  'shr dilute': 45146,
#  'eight ct': 30026,
#  '15 mln': 6337,
#  'vs five': 49031,
#  'mln revs': 36192,
#  'mln note': 36155,
#  ': Oper': 11655,
#  'net exclude': 37088,
#  'exclude extraordinary': 30516,
#  'seven mln': 44253,
#  'dlrs vs': 29501,
#  'vs four': 49033,
#  'four mln': 31535,
#  'mln tax': 36235,
#  ', offset': 2427,
#  'three mln': 47248,
#  'vs eight': 49028,
#  'eight mln': 30040,
#  'mln U.S.': 35920,
#  'U.S. oil': 21992,
#  'oil gas': 37735,
#  'gas property': 31792,
#  ...}

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
clf = MultinomialNB()
X_test = vectorizer.transform(X_test)

# %%
start = time.time()
pred = clf.fit(X_train, y_train).predict(X_test)
end = time.time()
print('elapsed time:', end - start)
# Out:
# elapsed time: 0.06474757194519043

# %%
# MACRO: Calculate metrics for each label, and find their unweighted mean. 
# This does not take label imbalance into account.
# MICRO: Calculate metrics globally by counting the total true positives, false negatives and false positives.
# WEIGHTED: Calculate metrics for each label, and find their average weighted by support (the number of true instances for each label). 
# This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.

def print_score(y_pred, y_test):
    print('f1 macro score:', f1_score(y_test,pred, average='macro'))
    print('f1 micro score:', f1_score(y_test,pred, average='micro'))
    print('f1 weighted score:', f1_score(y_test,pred, average='weighted'))
    print("----------------------")
    print('recall macro score:', recall_score(y_test,pred, average='macro'))
    print('recall micro score:', recall_score(y_test,pred, average='micro'))
    print('recall weighted score:', recall_score(y_test,pred, average='weighted'))
    print("----------------------")
    print('precision macro score:', precision_score(y_test,pred, average='macro'))
    print('precision micro score:', precision_score(y_test,pred, average='micro'))
    print('precision weighted score:', precision_score(y_test,pred, average='weighted'))
    # print("----------------------")
    # print('roc_auc_score macro score:', roc_auc_score(y_test,pred, average='macro', multi_class='ovr'))
    # print('roc_auc_score micro score:', roc_auc_score(y_test,pred, average='micro'))
    # print('roc_auc_score weighted score:', roc_auc_score(y_test,pred, average='weighted'))

# %%
print_score(pred, y_test)
# Out:
# f1 macro score: 0.7333948555137733
# f1 micro score: 0.898651789865179
# f1 weighted score: 0.896095136500183
# ----------------------
# recall macro score: 0.7248364130114443
# recall micro score: 0.898651789865179
# recall weighted score: 0.898651789865179
# ----------------------
# precision macro score: 0.7475823484580061
# precision micro score: 0.898651789865179
# precision weighted score: 0.8951212782108448
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ------------------------------------------------------
# # Remarques
# - On remaque que nous avons un bon f1 score ce qui indique que l'ont a pas trop de marges entre les classes. (Class Inbalance)
# - On remarque un bon score de recall.
#     - ```Recall is a metric that quantifies the number of correct positive predictions made out of all positive predictions that could have been made```
# - On remarque un bon score de precision.
#     - ```The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.```
#     - Le clf diférencie bien les topics

# %% [markdown]
# ## Amazon: Sentiment Analysis

# %% [markdown]
# ### Load Data

# %%
for root, _, files  in os.walk('../data/amazon/processed_acl/books/'):
    for f in files:
        file = root + f
        print('open', file)
        fd = open(file, 'r')
        for line in fd.readlines():
            print(line)
            break
# Out:
# open ../data/amazon/processed_acl/books/positive.review
# holes:1 must:1 top_secret:1 he:1 center:1 other_civilans:1 the_pacific:1 the_navy:1 a_lot:1 surface_must:1 this_book:1 man_named:1 <num>_feet:2 would_strongly:1 put_down:1 norman_johnson:1 lawes:1 a_top:1 the_support:1 ten:1 on_random:1 typhoon:1 a_phycologist:1 pressure:1 actually_an:1 a_day:1 johnson_is:1 strange:1 civilans_to:1 explored:1 support:1 pacific_ocean:1 pressure_to:1 back_some:1 read:1 however_on:1 it_still:1 stuck:1 a_remote:1 american:1 find_out:1 not_have:1 other_crichton:1 analysis.i:1 black_holes:1 after_a:1 misssion:1 some_strange:1 half_mile:1 <num>_navy:1 actually:1 remote_location:1 the_story:1 behavior:1 civilans:2 research_that:1 michael_crichton:1 excellant_novel:1 strongly_recommend:1 some:2 michael:1 does_not:1 strange_things:1 sphere_by:1 a_man:1 are_joined:1 mile_long:1 put:1 operations:1 spacecraft:2 around:1 joined:1 an_american:1 sea:1 a_half:1 pacific:1 the_civilans:1 information_on:1 day_under:1 half:1 that_some:1 lot:1 around_a:1 travels:1 ten_is:1 excellant:1 however:1 novels:3 find:1 brought:1 random:1 one:1 the_ocean:3 team:1 a_typhoon:1 read_the:1 all_of:1 feet_under:2 by_michael:1 by_<num>:1 out_that:1 crichton_novels:3 support_ships:1 the_other:1 sea_they:1 strongly:1 has_brought:1 earth.this:1 he_travels:1 quickly:1 novels_have:1 things_back:1 ocean_is:1 personel:1 recommend:1 remote:1 leave:1 explored_black:1 a_center:1 run_operations:1 certainly_the:1 is_stuck:1 have_read:1 random_things:1 center_<num>:1 of_all:1 out:1 best:1 help:2 still:1 novel:2 they_are:1 the_lawes:1 feet:2 phycologist_he:1 day:1 down:1 phycologist:1 analysis.i_would:1 they_quickly:1 help_the:1 <num>_other:1 spaceship:1 hardest_to:1 lot_of:1 one_of:1 help_them:1 spacecraft_they:1 comes:1 back_to:1 holes_and:1 researching_the:1 lawes_of:1 crichton_is:1 stuck_<num>:1 to_help:2 crichton:4 to_earth.this:1 navy_in:1 behavior_analysis.i:1 researching:1 book:1 they:3 learn:1 operations_however:1 with_<num>:1 them:1 to_put:1 typhoon_comes:1 the_spacecraft:2 was:1 live_while:1 surface_of:1 partial:1 still_has:1 <num>:4 navy:2 spaceship_the:1 ships:1 the_crichton:1 named:1 norman:1 of_information:1 american_ship:1 man:1 spacecraft_is:1 top:1 ocean_after:1 revolves_around:1 all:1 other:2 of_partial:1 team_of:1 novels_that:1 must_leave:1 leave_the:1 live:1 i_have:1 the_team:1 mile:1 story:1 travels_with:1 location:1 earth.this_novel:1 novel_does:1 johnson:2 johnson_johnson:1 that_i:1 ship:1 some_of:1 surface:3 brought_back:1 them_run:1 while:1 of_ten:1 secret:1 long:1 has_explored:1 is_actually:1 to_live:1 was_certainly:1 the_surface:3 to_behavior:1 learn_that:1 named_norman:1 run:1 quickly_learn:1 this_was:1 i:1 the_hardest:1 the_best:1 ships_on:1 research:1 travel_to:1 long_spaceship:1 an_excellant:1 joined_by:1 secret_misssion:1 the_sea:1 certainly:1 personel_to:1 surface_a:1 while_researching:1 not:1 revolves:1 they_find:1 hardest:1 location_in:1 back:2 navy_personel:1 story_revolves:1 ocean:4 things_from:1 partial_pressure:1 best_crichton:1 comes_and:1 civilans_travel:1 misssion_they:1 recommend_this:1 sphere:1 the_research:1 black:1 down_of:1 things:2 travel:1 ocean_to:2 ship_that:1 after:1 information:1 novel_this:1 #label#:positive
#
# open ../data/amazon/processed_acl/books/negative.review
# avid:1 your:1 horrible_book:1 wasted:1 use_it:1 the_entire:1 money.i:1 i_lit:1 i_read:1 lit:1 i_would:1 relationship:1 read:1 a_<num>:1 reader_and:1 reader:1 suffering:1 fire_one:1 i_had:1 year_old:2 gotten:1 horrible:3 lit_this:1 world...don't:1 my:2 one_star:1 headache_the:1 this_book:5 mom:1 was_horrible:1 friend:1 book_horrible:1 star_i:1 back:1 avid_reader:1 than_one:1 life:1 copy:1 rate_it:1 rate:1 my_mom:1 man:1 book_was:1 half:1 on_fire:1 and_then:1 reading_this:1 so:1 lower:1 i_could:1 <num>_year:2 than:1 time:2 half_of:1 time_spent:1 then:1 book:6 and_picked:1 possible:1 spent:1 old_man:1 up_after:1 one:2 horrible_if:1 one_less:1 part:1 was:2 entire:1 less_copy:1 to_rate:1 my_life:1 about_the:1 your_money.i:1 an_avid:1 if:1 the_relationship:1 use:1 a_headache:1 fire:1 lower_than:1 reading:1 a_friend:1 picked:1 purposes:1 then_got:1 waste_your:1 after_my:1 friend_i:1 old:2 man_and:1 and_i:1 world...don't_waste:1 book_on:1 part_about:1 copy_in:1 book_back:1 book_wasted:1 have_i:1 time_and:1 the_world...don't:1 better:1 if_it:1 star:1 got:1 mom_had:1 read_half:1 waste:1 after:1 i:6 about:1 could_use:1 had_gotten:1 was_possible:1 year:2 it_lower:1 relationship_the:1 wasted_my:1 wish:1 wish_i:1 boy:1 purposes_this:1 got_to:1 the_time:1 it_was:1 back_so:1 suffering_from:1 spent_reading:1 book_up:1 less:1 better_purposes:1 headache:1 possible_to:1 money.i_wish:1 for_better:1 it_suffering:1 the_part:1 gotten_it:1 picked_this:1 entire_time:1 old_boy:1 i_am:1 the_<num>:1 boy_had:1 <num>:2 so_i:1 #label#:negative
#
# open ../data/amazon/processed_acl/books/unlabeled.review
# is_such:1 feel:1 pages:1 if:1 his_kooky:1 to_kill:1 its_welcome:1 and_he:1 our_"hero":1 who_apparently:1 out_its:1 repeating:1 that_ranges:1 a_weakness:1 placed_the:1 he_hadn't:1 a_cast:1 florida_is:1 because:1 long:1 also_has:1 he_has:1 welcome_long:1 he_also:1 such_a:1 guys_try:1 you:1 equivalent:1 funny_writer:1 flat-out-evil.:1 writer:1 such:1 from_obnoxious:1 here:1 finally_ends:1 a_puppy:1 bad_guys:1 story_still:1 seems:1 puppy:1 world_here:1 it_finally:1 world:1 repeating_himself:1 writer_but:1 for_repeating:1 wears:1 characters:1 if_it:1 flat-out-evil._he:1 completely:1 corrupt_place:1 ends_you:1 equivalent_of:1 himself_especially:1 obnoxious:1 better:1 bitter:1 wears_out:1 ranges:1 of_bad:1 but_he:1 it_wears:1 scenes_where:1 emboldened:1 because_hiaasen's:1 the_many:1 scenes:1 feel_emboldened:1 hideaway_the:1 worked:1 have_worked:1 created_quite:1 finally:1 hideaway:1 florida:1 surgeons_who:1 murder:1 apparently_feel:1 also:1 where_clueless:1 central_theme:1 placed:1 weakness:1 where:1 the_equivalent:1 off-the-grid_hideaway:1 "hero":1 emboldened_because:1 try:1 little:1 kooky:1 himself:1 one-note:1 hiaasen's_south:1 in_his:1 off-the-grid:1 central:1 do_better:1 who:1 hiaasen_is:1 especially:1 kooky_off-the-grid:1 theme_seems:1 might_have:1 obnoxious_to:1 ranges_from:1 south_florida:1 try_to:1 the_central:1 a_completely:1 you_can:1 clueless_bad:1 he:3 theme:1 murder_at:1 corrupt:1 here_with:1 a_bitter:1 worked_if:1 its_center:1 characters_that:1 bad_cosmetic:1 funny:1 created:1 apparently:1 little_world:1 hiaasen's:1 many_scenes:1 kill_our:1 <num>:1 shorter:1 "hero"_in:1 still_might:1 story:1 quite_a:1 quite:1 his:1 ends:1 scourge_of:1 still:1 place_the:1 center:1 welcome:1 kill:1 puppy_murder:1 hadn't_placed:1 shorter_and:1 cosmetic_surgeons:1 might:1 has_created:1 hiaasen:1 a_funny:1 bitter_little:1 out:1 our:1 before_it:1 guys:1 cast_of:1 long_before:1 <num>_pages:1 many:1 south:1 place:1 cast:1 surgeons:1 were_<num>:1 weakness_for:1 bad:2 completely_corrupt:1 hadn't:1 pages_shorter:1 clueless:1 especially_the:1 the_scourge:1 scourge:1 before:1 center_but:1 the_story:1 seems_to:1 of_characters:1 to_flat-out-evil.:1 cosmetic:1 #label#:negative

# %%
rows = []

for root_topics, dirs_topic, _  in os.walk('../data/amazon/processed_acl/'):
    for topic in dirs_topic:
        for root_topic, _, files_topic in os.walk(root_topics + topic):
            for file in files_topic:
                print(topic, file)
                file = root_topic + "/" + file
                print('open', file)
                fd = open(file, 'r')
                for line in fd.readlines():
                    
                    # remove count
                    line = re.sub(r':\d', '', line)
                    
                    tokens = line.split()
                    sentence = ' '.join(tokens[:-1])
                    target = tokens[-1:]
                    if "positive" in str(target):
                        target = 1
                    elif "negative" in str(target):
                        target = 0
                    else:
                        print("error !!!!!", target)
                    
                    rows += [[topic, sentence, target]]
print(len(rows))
# Out:
# books positive.review
# open ../data/amazon/processed_acl/books/positive.review
# books negative.review
# open ../data/amazon/processed_acl/books/negative.review
# books unlabeled.review
# open ../data/amazon/processed_acl/books/unlabeled.review
# kitchen positive.review
# open ../data/amazon/processed_acl/kitchen/positive.review
# kitchen negative.review
# open ../data/amazon/processed_acl/kitchen/negative.review
# kitchen unlabeled.review
# open ../data/amazon/processed_acl/kitchen/unlabeled.review
# dvd positive.review
# open ../data/amazon/processed_acl/dvd/positive.review
# dvd negative.review
# open ../data/amazon/processed_acl/dvd/negative.review
# dvd unlabeled.review
# open ../data/amazon/processed_acl/dvd/unlabeled.review
# electronics positive.review
# open ../data/amazon/processed_acl/electronics/positive.review
# electronics negative.review
# open ../data/amazon/processed_acl/electronics/negative.review
# electronics unlabeled.review
# open ../data/amazon/processed_acl/electronics/unlabeled.review
# 27677

# %%
amazon_df = pd.DataFrame(rows, columns=['topic', 'sentence', 'target'])
amazon_df
# Out:
#              topic                                           sentence  target
# 0            books  holes must top_secret he center other_civilans...       1
# 1            books  i_think dr_dean reason oz medicine_which stori...       1
# 2            books  woman_the contains_the fan_i alex_ross(superma...       1
# 3            books  hurricane these_pages lost_innocence both at_h...       1
# 4            books  while commented the_rise if strong_emphasis fo...       1
# ...            ...                                                ...     ...
# 27672  electronics  came tighter front_of fit_tighter make bent_th...       1
# 27673  electronics  advice nothing_about code buying_a <num>_month...       0
# 27674  electronics  and_used peers_during her month_trip remote_ch...       1
# 27675  electronics  deal_with angriest_is <dash-num> me_angriest a...       0
# 27676  electronics  until_all i'll quality_is the_whole if day_to ...       0
#
# [27677 rows x 3 columns]

# %%
amazon_df['topic'].value_counts()
# Out:
# kitchen        7945
# electronics    7681
# books          6465
# dvd            5586
# Name: topic, dtype: int64

# %%
amazon_df['target'].value_counts()
# Out:
# 1    13882
# 0    13795
# Name: target, dtype: int64

# %%
vectorizer2 = CountVectorizer(max_features=50000)

# %%
X2 = amazon_df['sentence']
y2 = amazon_df['target']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=random_state)

# %%
start = time.time()
X_train2 = vectorizer2.fit_transform(X_train2)
end = time.time()
print('elapsed time:', end - start)
print("X_train2.shape", X_train2.shape)
# Out:
# elapsed time: 4.827284336090088
# X_train2.shape (19373, 50000)

# %%
X_test2 = vectorizer2.transform(X_test2)
print("X_test2.shape", X_test2.shape)
# Out:
# X_test2.shape (8304, 50000)

# %%
start = time.time()
pred2 = clf.fit(X_train2, y_train2).predict(X_test2)
end = time.time()
print('elapsed time:', end - start)
# Out:
# elapsed time: 0.04524874687194824

# %%
print('f1 macro score:', f1_score(y_test2,pred2, average='macro'))
print('f1 micro score:', f1_score(y_test2,pred2, average='micro'))
print('f1 weighted score:', f1_score(y_test2,pred2, average='weighted'))
print("----------------------")
print('recall macro score:', recall_score(y_test2,pred2, average='macro'))
print('recall micro score:', recall_score(y_test2,pred2, average='micro'))
print('recall weighted score:', recall_score(y_test2,pred2, average='weighted'))
print("----------------------")
print('precision macro score:', precision_score(y_test2,pred2, average='macro'))
print('precision micro score:', precision_score(y_test2,pred2, average='micro'))
print('precision weighted score:', precision_score(y_test2,pred2, average='weighted'))
# Out:
# f1 macro score: 0.885595809333078
# f1 micro score: 0.8855973025048169
# f1 weighted score: 0.8855956102435127
# ----------------------
# recall macro score: 0.8855992482206148
# recall micro score: 0.8855973025048169
# recall weighted score: 0.8855973025048169
# ----------------------
# precision macro score: 0.8856220646382892
# precision micro score: 0.8855973025048169
# precision weighted score: 0.8856236122716312

# %% [markdown]
# ------------------------------------------------------
# # Remarques
# - On remarque de très bon score. Le clf arrive à bien distinguer les classes.
# - La représentation en BOW est efficace.
